# %% [markdown]
# このファイルについて
# - about: 生の検索履歴データから異常なレコードを除去する前処理を行う
# - author: 松永

# %%
import os
from functools import reduce
import datetime as dt
import pandas as pd
import cudf
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ### ファイル名などの定数宣言

# %%
ORIGIN_DATA_DIR = '../../Input_original_data'
PROCESSED_DATA_DIR = '../../Input_processed_data'

IC_CSV = f'{PROCESSED_DATA_DIR}/road_master/ic_merged.csv'

ORIGIN_SEARCH_LOG_DIR = lambda month: f'{ORIGIN_DATA_DIR}/search_log/csv{month}'
ORIGIN_SEARCH_LOG_CSV_LIST = lambda date: [
    f'{ORIGIN_SEARCH_LOG_DIR(date[:6])}/DorapuraSearchLog-{date}.csv',
    f'{ORIGIN_SEARCH_LOG_DIR(date[:6])}/ExternalSvrSearchLog-{date}.csv',
    f'{ORIGIN_SEARCH_LOG_DIR(date[:6])}/SwitchSvrSearchLog-{date}.csv'
]

PROCESSED_SEARCH_LOG_DIR = lambda month: f'{PROCESSED_DATA_DIR}/search_records/csv{month}'
PROCESSED_SEARCH_LOG_CSV = lambda date: f'{PROCESSED_SEARCH_LOG_DIR(date[:6])}/record_{date}.csv'

SEARCH_LOG_COLNAME = [
    'date', 'start_code', 'start_name', 'end_code', 'end_name',
    'via1_code', 'via1_name', 'via2_code', 'via2_name', 'via3_code', 'via3_name',
    'spec_day', 'spec_time', 'spec_type', 'order', 'car_type', 'use_nexco', 'use_urban', 'use_local',
    'language'
]

# %% [markdown]
# ### 準備

# %% [markdown]
# #### 時刻操作系関数

# %%
def str2date(date_str, format='%Y%m%d'):
    '''
    文字列形式の日付 => datetime.Dateクラスの日付

    Parameters
    ----------
    date_str: str
    日付
    format: str
    日付文字列の形式

    Returns
    -------
    date: datetime.date
    '''
    date = dt.datetime.strptime(date_str, format).date()
    return date

def str2time(time_str, format='%H:%M'):
    '''
    文字列形式の時刻 => datetime.Timeクラスの時刻
    Parameters
    ----------
    time_str: str
    時刻
    format: str
    時刻文字列の形式

    Returns
    -------
    time: datetime.time
    '''
    time_datetime = dt.datetime.strptime(time_str, format)
    time = time_datetime.time()
    return time

# %% [markdown]
# #### ic_code => ic_name のDictを準備

# %%
df_ic = pd.read_csv(IC_CSV, dtype={'ic_code': str})
code2name = dict(zip(df_ic['ic_code'], df_ic['ic_name']))
name2code = {name: code for code, name in code2name.items()}

# %% [markdown]
# ### オリジナルデータ加工 -> CSV

# %%
def proc_spec_day(x):
    try:
        # dateに変換できるかどうか確認
        return str2date(x, format='%Y/%m/%d')
    except (ValueError, TypeError) as e:
        # print(e, x)
        return
    
def proc_spec_time(x):
    try:
        # dateに変換できるかどうか確認
        return str2time(x)
    except (ValueError, TypeError) as e:
        print(e, x)
        return


def preprocessing(df):
    # ICコードに”E”が含まれている行を除去
    df = df[df['start_code'].str.contains('E') == False]
    df = df[df['end_code'].str.contains('E') == False]

    # マスタデータに含まれないICコードが誤って記録されている行を除去
    df = df[df['start_code'].apply(lambda c: c in code2name)]
    df = df[df['end_code'].apply(lambda c: c in code2name)]

    # マスタデータに含まれないIC名称が誤って指定されている行を除去
    df = df[df['start_name'].apply(lambda n: n in name2code)]
    df = df[df['end_name'].apply(lambda n: n in name2code)]

    # 指定日に異常な日付が入っている行（e.g. 2021/04/31, 210327）を除去
    df['spec_day'] = df['spec_day'].apply(proc_spec_day)
    df = df[df['spec_day'].notna()]

    # 指定時間が”24:00”となっている行の指定日・指定時間を翌日に繰り上げ
    df['spec_day'] = df['spec_day'].mask(df['spec_time'] == '24:00', df['spec_day'] + dt.timedelta(days=1))
    df.replace({'spec_time': {'24:00': '0:00'}}, inplace=True)

    # 指定時間が\"24:12\"のように異常な行を除去
    df = df[df['spec_time'].str[:2] != '24']

    # 「指定言語」列を除去
    df.drop('language', axis=1, inplace=True)

    df.reset_index(drop=True, inplace=True)

    return df

# %%
# test
df = pd.read_csv(ORIGIN_SEARCH_LOG_CSV_LIST('20240201')[0],
          header=0, names=SEARCH_LOG_COLNAME,
          dtype={'start_code': str, 'end_code': str, 'via1_code': str, 'via2_code': str, 'via3_code': str})
df.head()
# Out:
#                   date start_code start_name end_code end_name via1_code  \
# 0  2024/02/01 00:00:00    5013001        学園南  1720081       下津       NaN
# 1  2024/02/01 00:00:00    1040141       鏡石ＰＡ  1030091      久留米       NaN
# 2  2024/02/01 00:00:01    1720031      岸和田和泉  1073006      摂津北       NaN
# 3  2024/02/01 00:00:01    214K071      圏央鶴ヶ島  1040086      宇都宮       NaN
# 4  2024/02/01 00:00:02    1010031         厚木  1120071     佐原香取       NaN
#
#   via1_name via2_code via2_name via3_code via3_name    spec_day spec_time  \
# 0       NaN       NaN       NaN       NaN       NaN  2024/02/01     00:00
# 1       NaN       NaN       NaN       NaN       NaN  2024/02/01     00:00
# 2       NaN       NaN       NaN       NaN       NaN  2024/01/31     11:50
# 3       NaN       NaN       NaN       NaN       NaN  2024/02/01     00:00
# 4       NaN       NaN       NaN       NaN       NaN  2024/01/31     00:00
#
#    spec_type  order  car_type  use_nexco  use_urban  use_local  language
# 0          1      2         2          1          1          1         0
# 1          1      2         2          1          1          1         0
# 2          1      2         2          1          1          1         0
# 3          1      2         2          1          1          1         0
# 4          1      2         4          1          1          1         0

# %% [markdown]
# ## main

# %%
start_date='20240201'
end_date= '20240506'

DAYS = [d.strftime('%Y%m%d') for d in pd.date_range(start_date, end_date, freq='1D')]

dtypes = {
    'start_code': str, 
    'end_code': str,
    'via1_code': str, 
    'via2_code': str,
    'via3_code': str,
}

for d in DAYS:
    df_day = None
    for csv in ORIGIN_SEARCH_LOG_CSV_LIST(d):
        if not os.path.exists(csv):
            continue

        df = pd.read_csv(csv, header=0, names=SEARCH_LOG_COLNAME, dtype=dtypes)
  
        df = preprocessing(df)
        print(os.path.basename(csv), len(df))

        df_day = pd.concat([df_day, df], ignore_index=True, copy=False)

    print('-'*30, f'[{d}] {len(df_day)} records', '-'*30)

    df_day.to_csv(PROCESSED_SEARCH_LOG_CSV(d), index=False)

print('='*40, 'finished', '='*40)
# Out:
# DorapuraSearchLog-20240201.csv 370168
# ExternalSvrSearchLog-20240201.csv 2700
# ------------------------------ [20240201] 372868 records ------------------------------
# DorapuraSearchLog-20240202.csv 368483
# ExternalSvrSearchLog-20240202.csv 2890
# ------------------------------ [20240202] 371373 records ------------------------------
# DorapuraSearchLog-20240203.csv 335306
# ExternalSvrSearchLog-20240203.csv 2009
# ------------------------------ [20240203] 337315 records ------------------------------
# DorapuraSearchLog-20240204.csv 326257
# ExternalSvrSearchLog-20240204.csv 1960
# ------------------------------ [20240204] 328217 records ------------------------------
# DorapuraSearchLog-20240205.csv 386425
# ExternalSvrSearchLog-20240205.csv 8152
# ------------------------------ [20240205] 394577 records ------------------------------
# DorapuraSearchLog-20240206.csv 360717
# ExternalSvrSearchLog-20240206.csv 8665
# ------------------------------ [20240206] 369382 records ------------------------------
# DorapuraSearchLog-20240207.csv 374218
# ExternalSvrSearchLog-20240207.csv 3981
# ------------------------------ [20240207] 378199 records ------------------------------
# DorapuraSearchLog-20240208.csv 372480
# ExternalSvrSearchLog-20240208.csv 2244
# ------------------------------ [20240208] 374724 records ------------------------------
# DorapuraSearchLog-20240209.csv 397006
# ExternalSvrSearchLog-20240209.csv 2405
# ------------------------------ [20240209] 399411 records ------------------------------
# DorapuraSearchLog-20240210.csv 368601
# ExternalSvrSearchLog-20240210.csv 2222
# ------------------------------ [20240210] 370823 records ------------------------------
# DorapuraSearchLog-20240211.csv 353585
# ExternalSvrSearchLog-20240211.csv 2047
# ------------------------------ [20240211] 355632 records ------------------------------
# DorapuraSearchLog-20240212.csv 369960
# ExternalSvrSearchLog-20240212.csv 2244
# ------------------------------ [20240212] 372204 records ------------------------------
# DorapuraSearchLog-20240213.csv 396384
# ExternalSvrSearchLog-20240213.csv 1880
# ------------------------------ [20240213] 398264 records ------------------------------
# DorapuraSearchLog-20240214.csv 363318
# ExternalSvrSearchLog-20240214.csv 1610
# ------------------------------ [20240214] 364928 records ------------------------------
# DorapuraSearchLog-20240215.csv 368419
# ExternalSvrSearchLog-20240215.csv 1894
# ------------------------------ [20240215] 370313 records ------------------------------
# DorapuraSearchLog-20240216.csv 369721
# ExternalSvrSearchLog-20240216.csv 2553
# ------------------------------ [20240216] 372274 records ------------------------------
# DorapuraSearchLog-20240217.csv 304618
# ExternalSvrSearchLog-20240217.csv 1972
# ------------------------------ [20240217] 306590 records ------------------------------
# DorapuraSearchLog-20240218.csv 299565
# ExternalSvrSearchLog-20240218.csv 1420
# ------------------------------ [20240218] 300985 records ------------------------------
# DorapuraSearchLog-20240219.csv 378434
# ExternalSvrSearchLog-20240219.csv 1942
# ------------------------------ [20240219] 380376 records ------------------------------
# DorapuraSearchLog-20240220.csv 362170
# ExternalSvrSearchLog-20240220.csv 1923
# ------------------------------ [20240220] 364093 records ------------------------------
# DorapuraSearchLog-20240221.csv 361258
# ExternalSvrSearchLog-20240221.csv 2561
# ------------------------------ [20240221] 363819 records ------------------------------
# DorapuraSearchLog-20240222.csv 379433
# ExternalSvrSearchLog-20240222.csv 3949
# ------------------------------ [20240222] 383382 records ------------------------------
# DorapuraSearchLog-20240223.csv 344472
# ExternalSvrSearchLog-20240223.csv 3542
# ------------------------------ [20240223] 348014 records ------------------------------
# DorapuraSearchLog-20240224.csv 342972
# ExternalSvrSearchLog-20240224.csv 2061
# ------------------------------ [20240224] 345033 records ------------------------------
# DorapuraSearchLog-20240225.csv 332667
# ExternalSvrSearchLog-20240225.csv 3012
# ------------------------------ [20240225] 335679 records ------------------------------
# DorapuraSearchLog-20240226.csv 405668
# ExternalSvrSearchLog-20240226.csv 2415
# ------------------------------ [20240226] 408083 records ------------------------------
# DorapuraSearchLog-20240227.csv 391158
# ExternalSvrSearchLog-20240227.csv 2667
# ------------------------------ [20240227] 393825 records ------------------------------
# DorapuraSearchLog-20240228.csv 379763
# ExternalSvrSearchLog-20240228.csv 1961
# ------------------------------ [20240228] 381724 records ------------------------------
# DorapuraSearchLog-20240229.csv 388733
# ExternalSvrSearchLog-20240229.csv 2072
# SwitchSvrSearchLog-20240229.csv 9
# ------------------------------ [20240229] 390814 records ------------------------------
# DorapuraSearchLog-20240301.csv 391244
# ExternalSvrSearchLog-20240301.csv 3264
# SwitchSvrSearchLog-20240301.csv 34
# ------------------------------ [20240301] 394542 records ------------------------------
# DorapuraSearchLog-20240302.csv 346499
# ExternalSvrSearchLog-20240302.csv 2611
# SwitchSvrSearchLog-20240302.csv 3
# ------------------------------ [20240302] 349113 records ------------------------------
# DorapuraSearchLog-20240303.csv 345547
# ExternalSvrSearchLog-20240303.csv 2132
# ------------------------------ [20240303] 347679 records ------------------------------
# DorapuraSearchLog-20240304.csv 426510
# ExternalSvrSearchLog-20240304.csv 2602
# SwitchSvrSearchLog-20240304.csv 3
# ------------------------------ [20240304] 429115 records ------------------------------
# DorapuraSearchLog-20240305.csv 397823
# ExternalSvrSearchLog-20240305.csv 2428
# ------------------------------ [20240305] 400251 records ------------------------------
# DorapuraSearchLog-20240306.csv 417815
# ExternalSvrSearchLog-20240306.csv 2746
# SwitchSvrSearchLog-20240306.csv 2
# ------------------------------ [20240306] 420563 records ------------------------------
# DorapuraSearchLog-20240307.csv 426861
# ExternalSvrSearchLog-20240307.csv 1966
# ------------------------------ [20240307] 428827 records ------------------------------
# DorapuraSearchLog-20240308.csv 183236
# ExternalSvrSearchLog-20240308.csv 3037
# SwitchSvrSearchLog-20240308.csv 275315
# ------------------------------ [20240308] 461588 records ------------------------------
# DorapuraSearchLog-20240309.csv 91189
# ExternalSvrSearchLog-20240309.csv 1986
# SwitchSvrSearchLog-20240309.csv 281361
# ------------------------------ [20240309] 374536 records ------------------------------
# DorapuraSearchLog-20240310.csv 338567
# ExternalSvrSearchLog-20240310.csv 1792
# SwitchSvrSearchLog-20240310.csv 21708
# ------------------------------ [20240310] 362067 records ------------------------------
# DorapuraSearchLog-20240311.csv 434320
# ExternalSvrSearchLog-20240311.csv 1830
# SwitchSvrSearchLog-20240311.csv 20359
# ------------------------------ [20240311] 456509 records ------------------------------
# DorapuraSearchLog-20240312.csv 424945
# ExternalSvrSearchLog-20240312.csv 2065
# SwitchSvrSearchLog-20240312.csv 15071
# ------------------------------ [20240312] 442081 records ------------------------------
# DorapuraSearchLog-20240313.csv 411152
# ExternalSvrSearchLog-20240313.csv 2187
# SwitchSvrSearchLog-20240313.csv 11371
# ------------------------------ [20240313] 424710 records ------------------------------
# DorapuraSearchLog-20240314.csv 418163
# ExternalSvrSearchLog-20240314.csv 2034
# SwitchSvrSearchLog-20240314.csv 9645
# ------------------------------ [20240314] 429842 records ------------------------------
# DorapuraSearchLog-20240315.csv 405099
# ExternalSvrSearchLog-20240315.csv 2515
# SwitchSvrSearchLog-20240315.csv 7157
# ------------------------------ [20240315] 414771 records ------------------------------
# DorapuraSearchLog-20240316.csv 291632
# ExternalSvrSearchLog-20240316.csv 1695
# SwitchSvrSearchLog-20240316.csv 4241
# ------------------------------ [20240316] 297568 records ------------------------------
# DorapuraSearchLog-20240317.csv 297009
# ExternalSvrSearchLog-20240317.csv 1892
# SwitchSvrSearchLog-20240317.csv 3935
# ------------------------------ [20240317] 302836 records ------------------------------
# DorapuraSearchLog-20240318.csv 368695
# ExternalSvrSearchLog-20240318.csv 2397
# SwitchSvrSearchLog-20240318.csv 6300
# ------------------------------ [20240318] 377392 records ------------------------------
# DorapuraSearchLog-20240319.csv 357144
# ExternalSvrSearchLog-20240319.csv 2867
# SwitchSvrSearchLog-20240319.csv 6371
# ------------------------------ [20240319] 366382 records ------------------------------
# DorapuraSearchLog-20240320.csv 325701
# ExternalSvrSearchLog-20240320.csv 2947
# SwitchSvrSearchLog-20240320.csv 5146
# ------------------------------ [20240320] 333794 records ------------------------------
# DorapuraSearchLog-20240321.csv 376167
# ExternalSvrSearchLog-20240321.csv 2688
# SwitchSvrSearchLog-20240321.csv 6970
# ------------------------------ [20240321] 385825 records ------------------------------
# DorapuraSearchLog-20240322.csv 364298
# ExternalSvrSearchLog-20240322.csv 2401
# SwitchSvrSearchLog-20240322.csv 5425
# ------------------------------ [20240322] 372124 records ------------------------------
# DorapuraSearchLog-20240323.csv 364946
# ExternalSvrSearchLog-20240323.csv 1827
# SwitchSvrSearchLog-20240323.csv 4474
# ------------------------------ [20240323] 371247 records ------------------------------
# DorapuraSearchLog-20240324.csv 349149
# ExternalSvrSearchLog-20240324.csv 1775
# SwitchSvrSearchLog-20240324.csv 5176
# ------------------------------ [20240324] 356100 records ------------------------------
# DorapuraSearchLog-20240325.csv 414247
# ExternalSvrSearchLog-20240325.csv 1940
# SwitchSvrSearchLog-20240325.csv 5696
# ------------------------------ [20240325] 421883 records ------------------------------
# DorapuraSearchLog-20240326.csv 407898
# ExternalSvrSearchLog-20240326.csv 2423
# SwitchSvrSearchLog-20240326.csv 5169
# ------------------------------ [20240326] 415490 records ------------------------------
# DorapuraSearchLog-20240327.csv 441797
# ExternalSvrSearchLog-20240327.csv 2417
# SwitchSvrSearchLog-20240327.csv 5291
# ------------------------------ [20240327] 449505 records ------------------------------
# DorapuraSearchLog-20240328.csv 452560
# ExternalSvrSearchLog-20240328.csv 2099
# SwitchSvrSearchLog-20240328.csv 6178
# ------------------------------ [20240328] 460837 records ------------------------------
# DorapuraSearchLog-20240329.csv 477379
# ExternalSvrSearchLog-20240329.csv 2587
# SwitchSvrSearchLog-20240329.csv 7243
# ------------------------------ [20240329] 487209 records ------------------------------
# DorapuraSearchLog-20240330.csv 374436
# ExternalSvrSearchLog-20240330.csv 1931
# SwitchSvrSearchLog-20240330.csv 5445
# ------------------------------ [20240330] 381812 records ------------------------------
# DorapuraSearchLog-20240331.csv 362502
# ExternalSvrSearchLog-20240331.csv 1764
# SwitchSvrSearchLog-20240331.csv 5815
# ------------------------------ [20240331] 370081 records ------------------------------
# DorapuraSearchLog-20240401.csv 454820
# ExternalSvrSearchLog-20240401.csv 2103
# SwitchSvrSearchLog-20240401.csv 5785
# ------------------------------ [20240401] 462708 records ------------------------------
# DorapuraSearchLog-20240402.csv 445613
# ExternalSvrSearchLog-20240402.csv 2160
# SwitchSvrSearchLog-20240402.csv 5771
# ------------------------------ [20240402] 453544 records ------------------------------
# DorapuraSearchLog-20240403.csv 422847
# ExternalSvrSearchLog-20240403.csv 2117
# SwitchSvrSearchLog-20240403.csv 4720
# ------------------------------ [20240403] 429684 records ------------------------------
# DorapuraSearchLog-20240404.csv 444258
# ExternalSvrSearchLog-20240404.csv 2381
# SwitchSvrSearchLog-20240404.csv 5305
# ------------------------------ [20240404] 451944 records ------------------------------
# DorapuraSearchLog-20240405.csv 446086
# ExternalSvrSearchLog-20240405.csv 2456
# SwitchSvrSearchLog-20240405.csv 4914
# ------------------------------ [20240405] 453456 records ------------------------------
# DorapuraSearchLog-20240406.csv 386577
# ExternalSvrSearchLog-20240406.csv 1595
# SwitchSvrSearchLog-20240406.csv 3390
# ------------------------------ [20240406] 391562 records ------------------------------
# DorapuraSearchLog-20240407.csv 372746
# ExternalSvrSearchLog-20240407.csv 1554
# SwitchSvrSearchLog-20240407.csv 3122
# ------------------------------ [20240407] 377422 records ------------------------------
# DorapuraSearchLog-20240408.csv 467510
# ExternalSvrSearchLog-20240408.csv 1967
# SwitchSvrSearchLog-20240408.csv 4264
# ------------------------------ [20240408] 473741 records ------------------------------
# DorapuraSearchLog-20240409.csv 454869
# ExternalSvrSearchLog-20240409.csv 2009
# SwitchSvrSearchLog-20240409.csv 3203
# ------------------------------ [20240409] 460081 records ------------------------------
# DorapuraSearchLog-20240410.csv 441520
# ExternalSvrSearchLog-20240410.csv 1785
# SwitchSvrSearchLog-20240410.csv 2226
# ------------------------------ [20240410] 445531 records ------------------------------
# DorapuraSearchLog-20240411.csv 443630
# ExternalSvrSearchLog-20240411.csv 1633
# SwitchSvrSearchLog-20240411.csv 2260
# ------------------------------ [20240411] 447523 records ------------------------------
# DorapuraSearchLog-20240412.csv 457082
# ExternalSvrSearchLog-20240412.csv 1810
# SwitchSvrSearchLog-20240412.csv 2208
# ------------------------------ [20240412] 461100 records ------------------------------
# DorapuraSearchLog-20240413.csv 393521
# ExternalSvrSearchLog-20240413.csv 1820
# SwitchSvrSearchLog-20240413.csv 2245
# ------------------------------ [20240413] 397586 records ------------------------------
# DorapuraSearchLog-20240414.csv 402930
# ExternalSvrSearchLog-20240414.csv 1836
# SwitchSvrSearchLog-20240414.csv 1386
# ------------------------------ [20240414] 406152 records ------------------------------
# DorapuraSearchLog-20240415.csv 501677
# ExternalSvrSearchLog-20240415.csv 1782
# SwitchSvrSearchLog-20240415.csv 2346
# ------------------------------ [20240415] 505805 records ------------------------------
# DorapuraSearchLog-20240416.csv 473225
# ExternalSvrSearchLog-20240416.csv 1900
# SwitchSvrSearchLog-20240416.csv 2079
# ------------------------------ [20240416] 477204 records ------------------------------
# DorapuraSearchLog-20240417.csv 473765
# ExternalSvrSearchLog-20240417.csv 2003
# SwitchSvrSearchLog-20240417.csv 2263
# ------------------------------ [20240417] 478031 records ------------------------------
# DorapuraSearchLog-20240418.csv 492750
# ExternalSvrSearchLog-20240418.csv 2118
# SwitchSvrSearchLog-20240418.csv 2192
# ------------------------------ [20240418] 497060 records ------------------------------
# DorapuraSearchLog-20240419.csv 542985
# ExternalSvrSearchLog-20240419.csv 1905
# SwitchSvrSearchLog-20240419.csv 3509
# ------------------------------ [20240419] 548399 records ------------------------------
# DorapuraSearchLog-20240420.csv 454309
# ExternalSvrSearchLog-20240420.csv 1573
# SwitchSvrSearchLog-20240420.csv 1774
# ------------------------------ [20240420] 457656 records ------------------------------
# DorapuraSearchLog-20240421.csv 455823
# ExternalSvrSearchLog-20240421.csv 1829
# SwitchSvrSearchLog-20240421.csv 1609
# ------------------------------ [20240421] 459261 records ------------------------------
# DorapuraSearchLog-20240422.csv 567615
# ExternalSvrSearchLog-20240422.csv 2155
# SwitchSvrSearchLog-20240422.csv 2106
# ------------------------------ [20240422] 571876 records ------------------------------
# DorapuraSearchLog-20240423.csv 518878
# ExternalSvrSearchLog-20240423.csv 1646
# SwitchSvrSearchLog-20240423.csv 4420
# ------------------------------ [20240423] 524944 records ------------------------------
# DorapuraSearchLog-20240424.csv 514852
# ExternalSvrSearchLog-20240424.csv 1539
# SwitchSvrSearchLog-20240424.csv 4331
# ------------------------------ [20240424] 520722 records ------------------------------
# DorapuraSearchLog-20240425.csv 517325
# ExternalSvrSearchLog-20240425.csv 1762
# SwitchSvrSearchLog-20240425.csv 4524
# ------------------------------ [20240425] 523611 records ------------------------------
# DorapuraSearchLog-20240426.csv 551906
# ExternalSvrSearchLog-20240426.csv 1905
# SwitchSvrSearchLog-20240426.csv 3727
# ------------------------------ [20240426] 557538 records ------------------------------
# DorapuraSearchLog-20240427.csv 523637
# ExternalSvrSearchLog-20240427.csv 2447
# SwitchSvrSearchLog-20240427.csv 3292
# ------------------------------ [20240427] 529376 records ------------------------------
# DorapuraSearchLog-20240428.csv 494934
# ExternalSvrSearchLog-20240428.csv 2287
# SwitchSvrSearchLog-20240428.csv 2495
# ------------------------------ [20240428] 499716 records ------------------------------
# DorapuraSearchLog-20240429.csv 515953
# ExternalSvrSearchLog-20240429.csv 2222
# SwitchSvrSearchLog-20240429.csv 2291
# ------------------------------ [20240429] 520466 records ------------------------------
# DorapuraSearchLog-20240430.csv 592062
# ExternalSvrSearchLog-20240430.csv 1639
# SwitchSvrSearchLog-20240430.csv 3565
# ------------------------------ [20240430] 597266 records ------------------------------
# DorapuraSearchLog-20240501.csv 576616
# ExternalSvrSearchLog-20240501.csv 1788
# SwitchSvrSearchLog-20240501.csv 2246
# ------------------------------ [20240501] 580650 records ------------------------------
# DorapuraSearchLog-20240502.csv 629975
# ExternalSvrSearchLog-20240502.csv 2630
# SwitchSvrSearchLog-20240502.csv 2256
# ------------------------------ [20240502] 634861 records ------------------------------
# DorapuraSearchLog-20240503.csv 518959
# ExternalSvrSearchLog-20240503.csv 3501
# SwitchSvrSearchLog-20240503.csv 1881
# ------------------------------ [20240503] 524341 records ------------------------------
# DorapuraSearchLog-20240504.csv 513225
# ExternalSvrSearchLog-20240504.csv 2724
# SwitchSvrSearchLog-20240504.csv 1929
# ------------------------------ [20240504] 517878 records ------------------------------
# DorapuraSearchLog-20240505.csv 516268
# ExternalSvrSearchLog-20240505.csv 3063
# SwitchSvrSearchLog-20240505.csv 1548
# ------------------------------ [20240505] 520879 records ------------------------------
# DorapuraSearchLog-20240506.csv 529769
# ExternalSvrSearchLog-20240506.csv 2716
# SwitchSvrSearchLog-20240506.csv 1709
# ------------------------------ [20240506] 534194 records ------------------------------
# ======================================== finished ========================================
