# %% [markdown]
# # このファイルについて
# - about: ドラぷら検索ログの簡略化
#     - カラムの限定
#     - コンテスト対象道路（関越道・東北道）を通過しない検索の除外
# - author: 松永

# %%
import os
import time
import pickle
from typing import Dict, List, Optional, Set
import networkx as nx
import numpy as np
import pandas as pd
import cudf

import warnings
warnings.simplefilter('ignore')

# %%
# data directory
DATA_DIR = '../../Input_processed_data'

# IC, 道路情報 csv
IC_CSV = f'{DATA_DIR}/road_master/ic_preprocessed.csv'
IC_NET_CSV = f'{DATA_DIR}/road_master/220303-doronet_ic.csv'
IC_SUBNET_CSV = f'{DATA_DIR}/road_master/icnet_sub.csv'

# 検索ログ csv
SEARCH_LOG_DIR = lambda month: f'{DATA_DIR}/search_records/csv{month}'
SEARCH_LOG_CSV = lambda date: f'{SEARCH_LOG_DIR(date[:6])}/record_{date}.csv'

# %% [markdown]
# # 準備

# %%
# モジュール内で前処理済み
df_ic = pd.read_csv(IC_CSV, dtype={'ic_code': str})
df_icnet = pd.read_csv(IC_NET_CSV, dtype={'start_code': str, 'end_code': str, 'road_code': str})
sub_icnet = pd.read_csv(IC_SUBNET_CSV, dtype={'start_code': str, 'end_code': str, 'road_code': str})

# %%
code2name = dict(zip(df_ic['ic_code'], df_ic['ic_name']))
name2code = {v: k for k, v in code2name.items()}

# %%
ic_graph = nx.from_pandas_edgelist(
    df_icnet, source='start_code', target='end_code',
    edge_attr=['distance', 'road_code', 'direction'], create_using=nx.DiGraph())

# %%
ic_nodes_set: set = set(ic_graph.nodes)

# %% [markdown]
# # 検索ログを簡略化

# %%
def get_log(date: str) -> cudf.DataFrame:
    type_map = {
        'start_code': str,
        'end_code': str,
        'via1_code': str,
        'via2_code': str,
        'via3_code': str,
        'order': str
    }

    if not os.path.exists(SEARCH_LOG_CSV(date)):
        return cudf.DataFrame()
    df = pd.read_csv(SEARCH_LOG_CSV(date), dtype=type_map)
    return cudf.from_pandas(df)

# %% [markdown]
# ## 列を選択

# %%
def simplify_search_log(df: cudf.DataFrame) -> cudf.DataFrame:
    # レコードを限定
    df_res = df.loc[(df['start_code'].isin(ic_nodes_set)) & (df['end_code'].isin(ic_nodes_set))]
    
    # 列を限定
    select_columns = ['date', 'start_code', 'end_code', 'spec_day', 'spec_time', 'spec_type', 'car_type']
    df_res = df_res.loc[:, select_columns].rename(columns={'date': 'datetime'})
    
    # 指定日時を1列にまとめる
    df_res = df_res.assign(spec_datetime=df_res['spec_day'] + ' ' + df_res['spec_time'])
    df_res.drop(['spec_day', 'spec_time'], axis=1, inplace=True)
    
    # 型変換
    df_res = df_res.astype({
        'start_code': 'category',
        'end_code': 'category',
        'spec_type': 'category',
        'car_type': 'category',
    })
    df_res = df_res.assign(
        datetime=cudf.to_datetime(df_res['datetime']),
        spec_datetime=cudf.to_datetime(df_res['spec_datetime'])
    )
    
    # 列並び替え
    select_columns = ['datetime', 'start_code', 'end_code', 'spec_datetime', 'spec_type', 'car_type']
    return df_res.loc[:, select_columns]

# %%
df_simple = simplify_search_log(get_log('20230901'))
print(df_simple.shape)
df_simple.head()
# Out:
# (373484, 6)
#              datetime start_code end_code       spec_datetime spec_type  \
# 0 2023-09-01 00:00:00    6001006  1400091 2023-09-01 07:00:00         1
# 1 2023-09-01 00:00:00    1461080  1040011 2023-08-31 08:00:00         1
# 2 2023-09-01 00:00:00    1072023  1612046 2023-10-21 15:00:00         1
# 3 2023-09-01 00:00:01    1461080  212B011 2023-09-01 00:00:00         1
# 4 2023-09-01 00:00:01    1800076  1040241 2023-08-31 23:50:00         1
#
#   car_type
# 0        3
# 1        2
# 2        2
# 3        2
# 4        2

# %% [markdown]
# ## 関越道・東北道を通過するレコードのみを抜き出す

# %% [markdown]
# ### 経路検索用プログラム

# %%
def __get_route(
    src: str, dest: str, route_dict: Dict[str, Dict[str, List[str]]]
) -> Optional[List[str]]:
    if not (src in ic_nodes_set and dest in ic_nodes_set):
        return []
    try:
        path = route_dict[src][dest]
        return path
    except: # 経路が存在しない, もしくはノードがグラフ上に存在しない場合
        return []

# %%
def get_route(
    src: str, 
    dest: str, 
    route_dict: Dict[str, Dict[str, List[str]]],
    excluded_ic_set: Set[str] = set(),
) -> List[str]:
    '''
    ic_graph上で出発地から目的地までの経路を得る関数

    Parameters
    --------------
    src: 出発ICコード
    dest: 目的ICコード
    '''
    path = __get_route(src, dest, route_dict=route_dict)
    
    if len(excluded_ic_set) > 0:
        path = [ic for ic in path if ic not in excluded_ic_set]
    return path

# %%
fname = './route_dict.pkl'

if os.path.exists(fname): # 経路マップがすでに存在しているとき、それを使う
    with open(fname, 'rb') as f:
        print('Loading IC Routes...')
        route_dict = pickle.load(f)
else: # 存在していなければ計算してバイナリで保存
    print('Calculating IC Routes...')
    route_dict = dict(nx.all_pairs_dijkstra_path(ic_graph, weight='distance'))
    
    with open(fname, 'wb') as f:
        pickle.dump(route_dict, f)
print('Finished.')
# Out:
# Loading IC Routes...
# Finished.

# %% [markdown]
# ### 対象道路のみを抽出

# %%
target_road_code_set = {'1800', '1040'}

# %%
def extract_road_related_queries(df_log: cudf.DataFrame, target_road_code_set: set) -> cudf.DataFrame:
    query_indices = []

    for i_query, record in enumerate(df_log.to_numpy()):
        start_code, end_code = record[[1, 2]]
        path = get_route(start_code, end_code, route_dict)
        # when the shortest path cannot be calculated
        if len(path) == 0:
            continue
        
        for i_segment, (start_code, end_code) in enumerate(zip(path, path[1:])):
            if ic_graph[start_code][end_code]['road_code'] in target_road_code_set:
                query_indices.append(i_query)
                break

    related_df_log = df_log.iloc[query_indices].reset_index(drop=True)
    return related_df_log

# %%
PERIOD_BLOCKS = [
    ('20210401', '20210630'),
    ('20210701', '20210930'),
    ('20211001', '20211231'),
    ('20220101', '20220331'),
    ('20220401', '20220630'),
    ('20220701', '20220930'),
    ('20221001', '20221231'),
    ('20230101', '20230331'),
    ('20230401', '20230630'),
    ('20230701', '20230930'),
]

# %%
OUTPUT_FILE = lambda date: f'{DATA_DIR}/simple_search_records/csv{date[:6]}/record_{date}.csv'

# %%
for start_date, end_date in PERIOD_BLOCKS:
    print('='*40, f'{start_date} -> {end_date}', '='*40)
    date_list = [d.strftime('%Y%m%d') for d in pd.date_range(start_date, end_date, freq='1D')]
    
    for i_date, target_date in enumerate(date_list):
        s = time.time()
        
        df_simple = simplify_search_log(get_log(target_date))
        df_related_log = extract_road_related_queries(df_simple, target_road_code_set)
        
        fname_out = OUTPUT_FILE(target_date)
        print(f'{target_date} | # of related queries: {len(df_related_log)} ({time.time() - s:.2f} [sec])')

        # os.makedirs(os.path.dirname(fname_out), exist_ok=True)
        # df_related_log.to_csv(fname_out, index=False)
# Out:
# ======================================== 20210401 -> 20210630 ========================================
# 20210401 | # of related queries: 64545 (15.53 [sec])
# 20210402 | # of related queries: 67265 (16.03 [sec])
# 20210403 | # of related queries: 58908 (13.96 [sec])
# 20210404 | # of related queries: 70583 (19.97 [sec])
# 20210405 | # of related queries: 78866 (22.43 [sec])
# 20210406 | # of related queries: 75476 (22.81 [sec])
# 20210407 | # of related queries: 74272 (22.27 [sec])
# 20210408 | # of related queries: 55110 (10.01 [sec])
# 20210409 | # of related queries: 58802 (10.16 [sec])
# 20210410 | # of related queries: 49978 (9.17 [sec])
# 20210411 | # of related queries: 47532 (9.09 [sec])
# 20210412 | # of related queries: 57933 (11.05 [sec])
# 20210413 | # of related queries: 55206 (10.54 [sec])
# 20210414 | # of related queries: 51629 (9.76 [sec])
# 20210415 | # of related queries: 53933 (10.25 [sec])
# 20210416 | # of related queries: 57364 (10.55 [sec])
# 20210417 | # of related queries: 57350 (12.06 [sec])
# 20210418 | # of related queries: 57994 (13.13 [sec])
# 20210419 | # of related queries: 65622 (13.65 [sec])
# 20210420 | # of related queries: 57382 (12.38 [sec])
# 20210421 | # of related queries: 55466 (11.75 [sec])
# 20210422 | # of related queries: 59832 (12.64 [sec])
# 20210423 | # of related queries: 64204 (13.06 [sec])
# 20210424 | # of related queries: 67021 (16.86 [sec])
# 20210425 | # of related queries: 65178 (15.08 [sec])
# 20210426 | # of related queries: 71622 (15.88 [sec])
# 20210427 | # of related queries: 73515 (16.06 [sec])
# 20210428 | # of related queries: 76886 (14.89 [sec])
# 20210429 | # of related queries: 77920 (14.29 [sec])
# 20210430 | # of related queries: 84982 (15.62 [sec])
# 20210501 | # of related queries: 70516 (15.65 [sec])
# 20210502 | # of related queries: 66904 (13.92 [sec])
# 20210503 | # of related queries: 61298 (10.57 [sec])
# 20210504 | # of related queries: 60662 (12.27 [sec])
# 20210505 | # of related queries: 53282 (11.64 [sec])
# 20210506 | # of related queries: 49471 (10.31 [sec])
# 20210507 | # of related queries: 47168 (8.43 [sec])
# 20210508 | # of related queries: 40783 (7.18 [sec])
# 20210509 | # of related queries: 36384 (6.41 [sec])
# 20210510 | # of related queries: 41459 (7.67 [sec])
# 20210511 | # of related queries: 39878 (7.50 [sec])
# 20210512 | # of related queries: 39589 (7.31 [sec])
# 20210513 | # of related queries: 41629 (7.53 [sec])
# 20210514 | # of related queries: 41786 (7.28 [sec])
# 20210515 | # of related queries: 36123 (6.33 [sec])
# 20210516 | # of related queries: 34141 (6.03 [sec])
# 20210517 | # of related queries: 40193 (7.40 [sec])
# 20210518 | # of related queries: 38113 (7.31 [sec])
# 20210519 | # of related queries: 39995 (7.74 [sec])
# 20210520 | # of related queries: 37569 (6.98 [sec])
# 20210521 | # of related queries: 41665 (7.85 [sec])
# 20210522 | # of related queries: 36646 (6.91 [sec])
# 20210523 | # of related queries: 34882 (6.90 [sec])
# 20210524 | # of related queries: 42395 (8.29 [sec])
# 20210525 | # of related queries: 42349 (8.38 [sec])
# 20210526 | # of related queries: 42676 (8.59 [sec])
# 20210527 | # of related queries: 42859 (7.94 [sec])
# 20210528 | # of related queries: 44785 (8.31 [sec])
# 20210529 | # of related queries: 41262 (7.69 [sec])
# 20210530 | # of related queries: 46704 (8.86 [sec])
# 20210531 | # of related queries: 49981 (9.22 [sec])
# 20210601 | # of related queries: 51876 (9.97 [sec])
# 20210602 | # of related queries: 54736 (9.84 [sec])
# 20210603 | # of related queries: 53057 (9.92 [sec])
# 20210604 | # of related queries: 58282 (10.63 [sec])
# 20210605 | # of related queries: 32310 (5.45 [sec])
# 20210606 | # of related queries: 30796 (5.14 [sec])
# 20210607 | # of related queries: 52097 (9.21 [sec])
# 20210608 | # of related queries: 56493 (9.85 [sec])
# 20210609 | # of related queries: 52972 (9.84 [sec])
# 20210610 | # of related queries: 56625 (10.09 [sec])
# 20210611 | # of related queries: 57218 (9.96 [sec])
# 20210612 | # of related queries: 52875 (8.89 [sec])
# 20210613 | # of related queries: 50188 (8.91 [sec])
# 20210614 | # of related queries: 58585 (10.60 [sec])
# 20210615 | # of related queries: 54190 (9.71 [sec])
# 20210616 | # of related queries: 54366 (9.74 [sec])
# 20210617 | # of related queries: 58364 (10.12 [sec])
# 20210618 | # of related queries: 59850 (10.60 [sec])
# 20210619 | # of related queries: 55544 (10.03 [sec])
# 20210620 | # of related queries: 51554 (9.38 [sec])
# 20210621 | # of related queries: 57657 (10.79 [sec])
# 20210622 | # of related queries: 58862 (10.69 [sec])
# 20210623 | # of related queries: 56548 (10.01 [sec])
# 20210624 | # of related queries: 62589 (10.93 [sec])
# 20210625 | # of related queries: 64529 (11.43 [sec])
# 20210626 | # of related queries: 57274 (9.90 [sec])
# 20210627 | # of related queries: 54182 (10.42 [sec])
# 20210628 | # of related queries: 58264 (11.39 [sec])
# 20210629 | # of related queries: 55385 (10.88 [sec])
# 20210630 | # of related queries: 56460 (11.01 [sec])
# ======================================== 20210701 -> 20210930 ========================================
# 20210701 | # of related queries: 57390 (11.32 [sec])
# 20210702 | # of related queries: 61488 (11.71 [sec])
# 20210703 | # of related queries: 53046 (9.87 [sec])
# 20210704 | # of related queries: 55155 (10.10 [sec])
# 20210705 | # of related queries: 60679 (11.50 [sec])
# 20210706 | # of related queries: 55884 (10.78 [sec])
# 20210707 | # of related queries: 59743 (11.06 [sec])
# 20210708 | # of related queries: 62967 (12.23 [sec])
# 20210709 | # of related queries: 69018 (13.04 [sec])
# 20210710 | # of related queries: 63126 (12.14 [sec])
# 20210711 | # of related queries: 66470 (14.20 [sec])
# 20210712 | # of related queries: 76049 (14.74 [sec])
# 20210713 | # of related queries: 72463 (14.05 [sec])
# 20210714 | # of related queries: 70013 (13.66 [sec])
# 20210715 | # of related queries: 73290 (14.75 [sec])
# 20210716 | # of related queries: 80217 (16.19 [sec])
# 20210717 | # of related queries: 76430 (14.34 [sec])
# 20210718 | # of related queries: 81399 (15.76 [sec])
# 20210719 | # of related queries: 111884 (22.56 [sec])
# 20210720 | # of related queries: 97762 (18.91 [sec])
# 20210721 | # of related queries: 106271 (20.07 [sec])
# 20210722 | # of related queries: 94622 (17.36 [sec])
# 20210723 | # of related queries: 83146 (15.31 [sec])
# 20210724 | # of related queries: 81461 (15.38 [sec])
# 20210725 | # of related queries: 66408 (12.83 [sec])
# 20210726 | # of related queries: 71090 (14.00 [sec])
# 20210727 | # of related queries: 73108 (14.34 [sec])
# 20210728 | # of related queries: 69857 (13.74 [sec])
# 20210729 | # of related queries: 70857 (14.72 [sec])
# 20210730 | # of related queries: 72262 (13.94 [sec])
# 20210731 | # of related queries: 71156 (14.71 [sec])
# 20210801 | # of related queries: 71125 (13.80 [sec])
# 20210802 | # of related queries: 73912 (14.74 [sec])
# 20210803 | # of related queries: 68162 (13.80 [sec])
# 20210804 | # of related queries: 72644 (14.69 [sec])
# 20210805 | # of related queries: 69705 (14.28 [sec])
# 20210806 | # of related queries: 74600 (15.31 [sec])
# 20210807 | # of related queries: 66168 (13.30 [sec])
# 20210808 | # of related queries: 64693 (12.93 [sec])
# 20210809 | # of related queries: 72044 (14.77 [sec])
# 20210810 | # of related queries: 79307 (15.61 [sec])
# 20210811 | # of related queries: 76703 (14.47 [sec])
# 20210812 | # of related queries: 68776 (13.45 [sec])
# 20210813 | # of related queries: 61627 (12.47 [sec])
# 20210814 | # of related queries: 58408 (11.71 [sec])
# 20210815 | # of related queries: 66224 (12.82 [sec])
# 20210816 | # of related queries: 59823 (12.03 [sec])
# 20210817 | # of related queries: 58255 (11.37 [sec])
# 20210818 | # of related queries: 61074 (11.67 [sec])
# 20210819 | # of related queries: 59776 (11.69 [sec])
# 20210820 | # of related queries: 59383 (11.48 [sec])
# 20210821 | # of related queries: 53847 (10.21 [sec])
# 20210822 | # of related queries: 48470 (9.72 [sec])
# 20210823 | # of related queries: 61677 (12.03 [sec])
# 20210824 | # of related queries: 61790 (12.38 [sec])
# 20210825 | # of related queries: 60850 (12.62 [sec])
# 20210826 | # of related queries: 59475 (12.29 [sec])
# 20210827 | # of related queries: 63665 (12.17 [sec])
# 20210828 | # of related queries: 56495 (11.10 [sec])
# 20210829 | # of related queries: 53759 (11.18 [sec])
# 20210830 | # of related queries: 61759 (13.03 [sec])
# 20210831 | # of related queries: 54096 (11.45 [sec])
# 20210901 | # of related queries: 55650 (11.35 [sec])
# 20210902 | # of related queries: 57936 (11.55 [sec])
# 20210903 | # of related queries: 54600 (11.20 [sec])
# 20210904 | # of related queries: 52021 (10.34 [sec])
# 20210905 | # of related queries: 50722 (11.50 [sec])
# 20210906 | # of related queries: 62239 (13.50 [sec])
# 20210907 | # of related queries: 58481 (11.67 [sec])
# 20210908 | # of related queries: 60399 (11.87 [sec])
# 20210909 | # of related queries: 65367 (12.49 [sec])
# 20210910 | # of related queries: 63963 (12.55 [sec])
# 20210911 | # of related queries: 61417 (11.37 [sec])
# 20210912 | # of related queries: 58566 (11.48 [sec])
# 20210913 | # of related queries: 67266 (13.18 [sec])
# 20210914 | # of related queries: 64474 (12.49 [sec])
# 20210915 | # of related queries: 60386 (11.77 [sec])
# 20210916 | # of related queries: 62005 (11.59 [sec])
# 20210917 | # of related queries: 66108 (12.57 [sec])
# 20210918 | # of related queries: 74785 (13.87 [sec])
# 20210919 | # of related queries: 73964 (13.60 [sec])
# 20210920 | # of related queries: 75557 (15.37 [sec])
# 20210921 | # of related queries: 75404 (14.02 [sec])
# 20210922 | # of related queries: 78664 (14.41 [sec])
# 20210923 | # of related queries: 75821 (14.62 [sec])
# 20210924 | # of related queries: 79262 (15.27 [sec])
# 20210925 | # of related queries: 67414 (13.08 [sec])
# 20210926 | # of related queries: 69596 (13.39 [sec])
# 20210927 | # of related queries: 70614 (14.20 [sec])
# 20210928 | # of related queries: 74029 (13.82 [sec])
# 20210929 | # of related queries: 71487 (13.62 [sec])
# 20210930 | # of related queries: 67797 (12.90 [sec])
# ======================================== 20211001 -> 20211231 ========================================
# 20211001 | # of related queries: 77479 (13.79 [sec])
# 20211002 | # of related queries: 77028 (13.62 [sec])
# 20211003 | # of related queries: 69848 (12.73 [sec])
# 20211004 | # of related queries: 74052 (13.21 [sec])
# 20211005 | # of related queries: 72995 (13.41 [sec])
# 20211006 | # of related queries: 70768 (12.96 [sec])
# 20211007 | # of related queries: 74710 (13.41 [sec])
# 20211008 | # of related queries: 79001 (14.11 [sec])
# 20211009 | # of related queries: 74226 (12.88 [sec])
# 20211010 | # of related queries: 68768 (12.60 [sec])
# 20211011 | # of related queries: 78289 (14.16 [sec])
# 20211012 | # of related queries: 67388 (12.56 [sec])
# 20211013 | # of related queries: 67713 (12.71 [sec])
# 20211014 | # of related queries: 77449 (13.89 [sec])
# 20211015 | # of related queries: 73614 (12.96 [sec])
# 20211016 | # of related queries: 68997 (12.07 [sec])
# 20211017 | # of related queries: 73546 (13.32 [sec])
# 20211018 | # of related queries: 73134 (13.24 [sec])
# 20211019 | # of related queries: 69042 (13.05 [sec])
# 20211020 | # of related queries: 76791 (16.11 [sec])
# 20211021 | # of related queries: 71835 (14.39 [sec])
# 20211022 | # of related queries: 78463 (16.85 [sec])
# 20211023 | # of related queries: 74786 (14.16 [sec])
# 20211024 | # of related queries: 68988 (13.15 [sec])
# 20211025 | # of related queries: 73669 (13.16 [sec])
# 20211026 | # of related queries: 84611 (19.23 [sec])
# 20211027 | # of related queries: 74339 (13.41 [sec])
# 20211028 | # of related queries: 75876 (13.24 [sec])
# 20211029 | # of related queries: 81288 (14.38 [sec])
# 20211030 | # of related queries: 75049 (13.89 [sec])
# 20211031 | # of related queries: 70732 (14.56 [sec])
# 20211101 | # of related queries: 84158 (16.47 [sec])
# 20211102 | # of related queries: 93229 (17.78 [sec])
# 20211103 | # of related queries: 117012 (20.84 [sec])
# 20211104 | # of related queries: 103011 (20.69 [sec])
# 20211105 | # of related queries: 99735 (19.23 [sec])
# 20211106 | # of related queries: 95506 (17.52 [sec])
# 20211107 | # of related queries: 81160 (14.60 [sec])
# 20211108 | # of related queries: 86824 (16.15 [sec])
# 20211109 | # of related queries: 85121 (15.92 [sec])
# 20211110 | # of related queries: 81472 (15.85 [sec])
# 20211111 | # of related queries: 81679 (15.54 [sec])
# 20211112 | # of related queries: 87806 (16.18 [sec])
# 20211113 | # of related queries: 80332 (14.81 [sec])
# 20211114 | # of related queries: 75995 (15.13 [sec])
# 20211115 | # of related queries: 81830 (16.48 [sec])
# 20211116 | # of related queries: 76977 (15.61 [sec])
# 20211117 | # of related queries: 75338 (15.98 [sec])
# 20211118 | # of related queries: 80130 (16.09 [sec])
# 20211119 | # of related queries: 89303 (17.58 [sec])
# 20211120 | # of related queries: 83544 (15.05 [sec])
# 20211121 | # of related queries: 78695 (15.15 [sec])
# 20211122 | # of related queries: 85346 (15.77 [sec])
# 20211123 | # of related queries: 72800 (13.95 [sec])
# 20211124 | # of related queries: 76594 (14.48 [sec])
# 20211125 | # of related queries: 71547 (13.42 [sec])
# 20211126 | # of related queries: 76083 (14.29 [sec])
# 20211127 | # of related queries: 81585 (17.90 [sec])
# 20211128 | # of related queries: 102269 (32.91 [sec])
# 20211129 | # of related queries: 69392 (14.23 [sec])
# 20211130 | # of related queries: 67603 (13.87 [sec])
# 20211201 | # of related queries: 66230 (13.43 [sec])
# 20211202 | # of related queries: 69697 (14.53 [sec])
# 20211203 | # of related queries: 75030 (14.57 [sec])
# 20211204 | # of related queries: 64902 (13.18 [sec])
# 20211205 | # of related queries: 65587 (13.57 [sec])
# 20211206 | # of related queries: 70529 (14.88 [sec])
# 20211207 | # of related queries: 67756 (14.15 [sec])
# 20211208 | # of related queries: 66341 (14.28 [sec])
# 20211209 | # of related queries: 67508 (14.48 [sec])
# 20211210 | # of related queries: 74275 (14.97 [sec])
# 20211211 | # of related queries: 68232 (14.22 [sec])
# 20211212 | # of related queries: 66953 (14.45 [sec])
# 20211213 | # of related queries: 73001 (15.59 [sec])
# 20211214 | # of related queries: 66994 (14.13 [sec])
# 20211215 | # of related queries: 62200 (13.53 [sec])
# 20211216 | # of related queries: 63376 (13.39 [sec])
# 20211217 | # of related queries: 64030 (13.17 [sec])
# 20211218 | # of related queries: 76175 (14.09 [sec])
# 20211219 | # of related queries: 88630 (26.71 [sec])
# 20211220 | # of related queries: 101869 (33.27 [sec])
# 20211221 | # of related queries: 97319 (31.03 [sec])
# 20211222 | # of related queries: 113385 (41.54 [sec])
# 20211223 | # of related queries: 117296 (43.85 [sec])
# 20211224 | # of related queries: 118636 (44.01 [sec])
# 20211225 | # of related queries: 115624 (40.45 [sec])
# 20211226 | # of related queries: 101914 (26.63 [sec])
# 20211227 | # of related queries: 108257 (26.86 [sec])
# 20211228 | # of related queries: 121400 (28.27 [sec])
# 20211229 | # of related queries: 104650 (26.76 [sec])
# 20211230 | # of related queries: 95258 (24.24 [sec])
# 20211231 | # of related queries: 83622 (21.05 [sec])
# ======================================== 20220101 -> 20220331 ========================================
# 20220101 | # of related queries: 96423 (23.23 [sec])
# 20220102 | # of related queries: 96877 (24.10 [sec])
# 20220103 | # of related queries: 103020 (24.16 [sec])
# 20220104 | # of related queries: 95709 (22.70 [sec])
# 20220105 | # of related queries: 93786 (21.71 [sec])
# 20220106 | # of related queries: 87361 (21.53 [sec])
# 20220107 | # of related queries: 97705 (22.13 [sec])
# 20220108 | # of related queries: 87894 (20.75 [sec])
# 20220109 | # of related queries: 78773 (19.63 [sec])
# 20220110 | # of related queries: 74865 (19.23 [sec])
# 20220111 | # of related queries: 84114 (20.71 [sec])
# 20220112 | # of related queries: 83244 (19.25 [sec])
# 20220113 | # of related queries: 79006 (18.94 [sec])
# 20220114 | # of related queries: 81417 (18.77 [sec])
# 20220115 | # of related queries: 69806 (16.88 [sec])
# 20220116 | # of related queries: 64745 (16.83 [sec])
# 20220117 | # of related queries: 76259 (19.38 [sec])
# 20220118 | # of related queries: 77501 (18.73 [sec])
# 20220119 | # of related queries: 72999 (17.79 [sec])
# 20220120 | # of related queries: 71221 (16.58 [sec])
# 20220121 | # of related queries: 81734 (18.56 [sec])
# 20220122 | # of related queries: 60559 (12.72 [sec])
# 20220123 | # of related queries: 55590 (10.78 [sec])
# 20220124 | # of related queries: 63177 (12.25 [sec])
# 20220125 | # of related queries: 58023 (11.21 [sec])
# 20220126 | # of related queries: 60731 (10.88 [sec])
# 20220127 | # of related queries: 57388 (10.16 [sec])
# 20220128 | # of related queries: 60122 (10.07 [sec])
# 20220129 | # of related queries: 53655 (9.16 [sec])
# 20220130 | # of related queries: 53194 (9.93 [sec])
# 20220131 | # of related queries: 58640 (10.93 [sec])
# 20220201 | # of related queries: 58312 (10.93 [sec])
# 20220202 | # of related queries: 58360 (10.78 [sec])
# 20220203 | # of related queries: 55441 (10.32 [sec])
# 20220204 | # of related queries: 65422 (10.89 [sec])
# 20220205 | # of related queries: 54775 (9.19 [sec])
# 20220206 | # of related queries: 53016 (9.32 [sec])
# 20220207 | # of related queries: 59302 (10.82 [sec])
# 20220208 | # of related queries: 53663 (10.01 [sec])
# 20220209 | # of related queries: 53889 (9.82 [sec])
# 20220210 | # of related queries: 71003 (11.37 [sec])
# 20220211 | # of related queries: 63546 (10.71 [sec])
# 20220212 | # of related queries: 55850 (9.78 [sec])
# 20220213 | # of related queries: 54400 (9.53 [sec])
# 20220214 | # of related queries: 59138 (10.56 [sec])
# 20220215 | # of related queries: 57365 (10.25 [sec])
# 20220216 | # of related queries: 57395 (10.45 [sec])
# 20220217 | # of related queries: 59770 (10.31 [sec])
# 20220218 | # of related queries: 64095 (10.85 [sec])
# 20220219 | # of related queries: 58490 (10.24 [sec])
# 20220220 | # of related queries: 60528 (10.57 [sec])
# 20220221 | # of related queries: 81385 (12.92 [sec])
# 20220222 | # of related queries: 73128 (12.03 [sec])
# 20220223 | # of related queries: 65001 (11.33 [sec])
# 20220224 | # of related queries: 65863 (11.44 [sec])
# 20220225 | # of related queries: 68314 (11.64 [sec])
# 20220226 | # of related queries: 63501 (10.78 [sec])
# 20220227 | # of related queries: 60353 (10.81 [sec])
# 20220228 | # of related queries: 66100 (12.19 [sec])
# 20220301 | # of related queries: 61647 (11.76 [sec])
# 20220302 | # of related queries: 67429 (12.91 [sec])
# 20220303 | # of related queries: 60689 (11.46 [sec])
# 20220304 | # of related queries: 67878 (12.37 [sec])
# 20220305 | # of related queries: 65020 (11.46 [sec])
# 20220306 | # of related queries: 67330 (11.94 [sec])
# 20220307 | # of related queries: 74781 (13.45 [sec])
# 20220308 | # of related queries: 69965 (12.52 [sec])
# 20220309 | # of related queries: 66137 (12.39 [sec])
# 20220310 | # of related queries: 69030 (12.79 [sec])
# 20220311 | # of related queries: 73018 (13.11 [sec])
# 20220312 | # of related queries: 68911 (12.47 [sec])
# 20220313 | # of related queries: 68784 (12.94 [sec])
# 20220314 | # of related queries: 76160 (15.61 [sec])
# 20220315 | # of related queries: 76461 (16.41 [sec])
# 20220316 | # of related queries: 76165 (16.21 [sec])
# 20220317 | # of related queries: 101268 (15.00 [sec])
# 20220318 | # of related queries: 95416 (15.65 [sec])
# 20220319 | # of related queries: 93187 (15.19 [sec])
# 20220320 | # of related queries: 81848 (13.89 [sec])
# 20220321 | # of related queries: 83504 (14.65 [sec])
# 20220322 | # of related queries: 79148 (14.46 [sec])
# 20220323 | # of related queries: 74272 (14.02 [sec])
# 20220324 | # of related queries: 75502 (14.09 [sec])
# 20220325 | # of related queries: 77954 (14.17 [sec])
# 20220326 | # of related queries: 80895 (14.59 [sec])
# 20220327 | # of related queries: 76973 (14.18 [sec])
# 20220328 | # of related queries: 82489 (15.00 [sec])
# 20220329 | # of related queries: 78619 (14.84 [sec])
# 20220330 | # of related queries: 79561 (14.36 [sec])
# 20220331 | # of related queries: 88875 (16.49 [sec])
# ======================================== 20220401 -> 20220630 ========================================
# 20220401 | # of related queries: 95810 (19.35 [sec])
# 20220402 | # of related queries: 93051 (19.50 [sec])
# 20220403 | # of related queries: 85742 (16.00 [sec])
# 20220404 | # of related queries: 88998 (16.51 [sec])
# 20220405 | # of related queries: 79811 (14.99 [sec])
# 20220406 | # of related queries: 79686 (14.86 [sec])
# 20220407 | # of related queries: 86274 (16.77 [sec])
# 20220408 | # of related queries: 87093 (16.55 [sec])
# 20220409 | # of related queries: 77733 (13.94 [sec])
# 20220410 | # of related queries: 79349 (14.47 [sec])
# 20220411 | # of related queries: 84549 (15.88 [sec])
# 20220412 | # of related queries: 81019 (15.11 [sec])
# 20220413 | # of related queries: 81814 (17.01 [sec])
# 20220414 | # of related queries: 79925 (15.48 [sec])
# 20220415 | # of related queries: 84661 (15.89 [sec])
# 20220416 | # of related queries: 86937 (15.92 [sec])
# 20220417 | # of related queries: 77590 (13.96 [sec])
# 20220418 | # of related queries: 87647 (15.90 [sec])
# 20220419 | # of related queries: 80147 (14.58 [sec])
# 20220420 | # of related queries: 78673 (14.37 [sec])
# 20220421 | # of related queries: 82579 (15.27 [sec])
# 20220422 | # of related queries: 91155 (15.98 [sec])
# 20220423 | # of related queries: 84004 (14.80 [sec])
# 20220424 | # of related queries: 94548 (17.17 [sec])
# 20220425 | # of related queries: 97321 (18.09 [sec])
# 20220426 | # of related queries: 89876 (16.63 [sec])
# 20220427 | # of related queries: 93036 (17.34 [sec])
# 20220428 | # of related queries: 107670 (20.06 [sec])
# 20220429 | # of related queries: 116273 (21.23 [sec])
# 20220430 | # of related queries: 115866 (21.15 [sec])
# 20220501 | # of related queries: 126796 (21.50 [sec])
# 20220502 | # of related queries: 151732 (25.65 [sec])
# 20220503 | # of related queries: 124436 (21.15 [sec])
# 20220504 | # of related queries: 111386 (20.94 [sec])
# 20220505 | # of related queries: 102151 (19.50 [sec])
# 20220506 | # of related queries: 92174 (16.68 [sec])
# 20220507 | # of related queries: 85605 (16.55 [sec])
# 20220508 | # of related queries: 72967 (13.95 [sec])
# 20220509 | # of related queries: 78590 (14.73 [sec])
# 20220510 | # of related queries: 75834 (14.68 [sec])
# 20220511 | # of related queries: 70711 (12.99 [sec])
# 20220512 | # of related queries: 73016 (13.64 [sec])
# 20220513 | # of related queries: 77558 (14.26 [sec])
# 20220514 | # of related queries: 73954 (13.77 [sec])
# 20220515 | # of related queries: 74475 (14.31 [sec])
# 20220516 | # of related queries: 75429 (13.97 [sec])
# 20220517 | # of related queries: 76398 (14.67 [sec])
# 20220518 | # of related queries: 73056 (13.89 [sec])
# 20220519 | # of related queries: 83710 (15.38 [sec])
# 20220520 | # of related queries: 81012 (13.96 [sec])
# 20220521 | # of related queries: 71978 (12.10 [sec])
# 20220522 | # of related queries: 73365 (12.64 [sec])
# 20220523 | # of related queries: 85547 (15.20 [sec])
# 20220524 | # of related queries: 82610 (14.82 [sec])
# 20220525 | # of related queries: 74270 (13.33 [sec])
# 20220526 | # of related queries: 77707 (15.08 [sec])
# 20220527 | # of related queries: 81002 (15.76 [sec])
# 20220528 | # of related queries: 75834 (15.65 [sec])
# 20220529 | # of related queries: 75060 (15.67 [sec])
# 20220530 | # of related queries: 81674 (18.17 [sec])
# 20220531 | # of related queries: 78771 (16.28 [sec])
# 20220601 | # of related queries: 75306 (16.31 [sec])
# 20220602 | # of related queries: 72444 (15.36 [sec])
# 20220603 | # of related queries: 83748 (15.97 [sec])
# 20220604 | # of related queries: 73443 (15.13 [sec])
# 20220605 | # of related queries: 63936 (12.94 [sec])
# 20220606 | # of related queries: 77170 (13.97 [sec])
# 20220607 | # of related queries: 75721 (14.00 [sec])
# 20220608 | # of related queries: 73443 (13.19 [sec])
# 20220609 | # of related queries: 74936 (14.36 [sec])
# 20220610 | # of related queries: 78786 (13.50 [sec])
# 20220611 | # of related queries: 67474 (12.02 [sec])
# 20220612 | # of related queries: 70955 (13.96 [sec])
# 20220613 | # of related queries: 79316 (15.45 [sec])
# 20220614 | # of related queries: 71114 (13.02 [sec])
# 20220615 | # of related queries: 77227 (14.66 [sec])
# 20220616 | # of related queries: 75803 (13.46 [sec])
# 20220617 | # of related queries: 77522 (13.72 [sec])
# 20220618 | # of related queries: 68432 (13.26 [sec])
# 20220619 | # of related queries: 66553 (12.26 [sec])
# 20220620 | # of related queries: 79736 (15.58 [sec])
# 20220621 | # of related queries: 69151 (13.25 [sec])
# 20220622 | # of related queries: 73023 (14.22 [sec])
# 20220623 | # of related queries: 71938 (13.66 [sec])
# 20220624 | # of related queries: 75546 (13.59 [sec])
# 20220625 | # of related queries: 68883 (13.22 [sec])
# 20220626 | # of related queries: 67462 (12.40 [sec])
# 20220627 | # of related queries: 73131 (13.13 [sec])
# 20220628 | # of related queries: 70053 (12.75 [sec])
# 20220629 | # of related queries: 69430 (12.53 [sec])
# 20220630 | # of related queries: 70670 (12.27 [sec])
# ======================================== 20220701 -> 20220930 ========================================
# 20220701 | # of related queries: 73387 (12.23 [sec])
# 20220702 | # of related queries: 63660 (11.09 [sec])
# 20220703 | # of related queries: 68246 (12.07 [sec])
# 20220704 | # of related queries: 79875 (14.45 [sec])
# 20220705 | # of related queries: 70181 (12.69 [sec])
# 20220706 | # of related queries: 74052 (13.39 [sec])
# 20220707 | # of related queries: 73835 (13.06 [sec])
# 20220708 | # of related queries: 70220 (12.32 [sec])
# 20220709 | # of related queries: 64203 (11.08 [sec])
# 20220710 | # of related queries: 65361 (11.60 [sec])
# 20220711 | # of related queries: 82124 (14.67 [sec])
# 20220712 | # of related queries: 70292 (12.60 [sec])
# 20220713 | # of related queries: 77221 (13.86 [sec])
# 20220714 | # of related queries: 73684 (13.21 [sec])
# 20220715 | # of related queries: 81570 (13.66 [sec])
# 20220716 | # of related queries: 86026 (13.45 [sec])
# 20220717 | # of related queries: 80072 (15.00 [sec])
# 20220718 | # of related queries: 79010 (13.92 [sec])
# 20220719 | # of related queries: 77790 (13.60 [sec])
# 20220720 | # of related queries: 76014 (13.67 [sec])
# 20220721 | # of related queries: 80720 (14.99 [sec])
# 20220722 | # of related queries: 78224 (13.89 [sec])
# 20220723 | # of related queries: 75282 (13.39 [sec])
# 20220724 | # of related queries: 77988 (13.45 [sec])
# 20220725 | # of related queries: 84871 (14.97 [sec])
# 20220726 | # of related queries: 93270 (15.51 [sec])
# 20220727 | # of related queries: 83927 (14.43 [sec])
# 20220728 | # of related queries: 84054 (14.72 [sec])
# 20220729 | # of related queries: 89158 (15.82 [sec])
# 20220730 | # of related queries: 92945 (16.86 [sec])
# 20220731 | # of related queries: 92489 (16.10 [sec])
# 20220801 | # of related queries: 100751 (17.66 [sec])
# 20220802 | # of related queries: 98804 (17.63 [sec])
# 20220803 | # of related queries: 102804 (18.41 [sec])
# 20220804 | # of related queries: 103390 (16.94 [sec])
# 20220805 | # of related queries: 105185 (18.51 [sec])
# 20220806 | # of related queries: 101869 (18.28 [sec])
# 20220807 | # of related queries: 103646 (19.21 [sec])
# 20220808 | # of related queries: 123964 (22.62 [sec])
# 20220809 | # of related queries: 118000 (21.60 [sec])
# 20220810 | # of related queries: 130368 (23.70 [sec])
# 20220811 | # of related queries: 115002 (20.57 [sec])
# 20220812 | # of related queries: 106594 (19.11 [sec])
# 20220813 | # of related queries: 103573 (19.21 [sec])
# 20220814 | # of related queries: 108985 (19.73 [sec])
# 20220815 | # of related queries: 101900 (18.03 [sec])
# 20220816 | # of related queries: 98967 (18.14 [sec])
# 20220817 | # of related queries: 94959 (17.45 [sec])
# 20220818 | # of related queries: 96368 (16.64 [sec])
# 20220819 | # of related queries: 120709 (21.07 [sec])
# 20220820 | # of related queries: 99294 (16.84 [sec])
# 20220821 | # of related queries: 96214 (17.69 [sec])
# 20220822 | # of related queries: 101422 (17.64 [sec])
# 20220823 | # of related queries: 105008 (19.07 [sec])
# 20220824 | # of related queries: 102943 (18.36 [sec])
# 20220825 | # of related queries: 103690 (17.92 [sec])
# 20220826 | # of related queries: 104218 (17.33 [sec])
# 20220827 | # of related queries: 88937 (15.31 [sec])
# 20220828 | # of related queries: 92511 (15.28 [sec])
# 20220829 | # of related queries: 108464 (19.36 [sec])
# 20220830 | # of related queries: 99897 (17.33 [sec])
# 20220831 | # of related queries: 86087 (15.68 [sec])
# 20220901 | # of related queries: 100048 (16.10 [sec])
# 20220902 | # of related queries: 111047 (18.16 [sec])
# 20220903 | # of related queries: 83315 (14.64 [sec])
# 20220904 | # of related queries: 85968 (15.46 [sec])
# 20220905 | # of related queries: 108369 (19.09 [sec])
# 20220906 | # of related queries: 98790 (17.99 [sec])
# 20220907 | # of related queries: 102846 (18.55 [sec])
# 20220908 | # of related queries: 103392 (18.25 [sec])
# 20220909 | # of related queries: 103613 (17.18 [sec])
# 20220910 | # of related queries: 93730 (16.42 [sec])
# 20220911 | # of related queries: 95788 (17.19 [sec])
# 20220912 | # of related queries: 113518 (19.67 [sec])
# 20220913 | # of related queries: 109497 (18.96 [sec])
# 20220914 | # of related queries: 110578 (19.02 [sec])
# 20220915 | # of related queries: 116418 (19.92 [sec])
# 20220916 | # of related queries: 123782 (19.64 [sec])
# 20220917 | # of related queries: 109956 (17.23 [sec])
# 20220918 | # of related queries: 94992 (15.61 [sec])
# 20220919 | # of related queries: 102735 (17.95 [sec])
# 20220920 | # of related queries: 115657 (19.39 [sec])
# 20220921 | # of related queries: 107347 (18.26 [sec])
# 20220922 | # of related queries: 111795 (19.24 [sec])
# 20220923 | # of related queries: 99812 (16.95 [sec])
# 20220924 | # of related queries: 101744 (17.99 [sec])
# 20220925 | # of related queries: 96798 (17.34 [sec])
# 20220926 | # of related queries: 105371 (19.29 [sec])
# 20220927 | # of related queries: 107238 (19.40 [sec])
# 20220928 | # of related queries: 112116 (19.43 [sec])
# 20220929 | # of related queries: 111214 (19.30 [sec])
# 20220930 | # of related queries: 114844 (19.45 [sec])
# ======================================== 20221001 -> 20221231 ========================================
# 20221001 | # of related queries: 100921 (16.60 [sec])
# 20221002 | # of related queries: 98835 (16.31 [sec])
# 20221003 | # of related queries: 115227 (19.53 [sec])
# 20221004 | # of related queries: 107011 (18.16 [sec])
# 20221005 | # of related queries: 103038 (17.63 [sec])
# 20221006 | # of related queries: 105959 (17.78 [sec])
# 20221007 | # of related queries: 123118 (20.50 [sec])
# 20221008 | # of related queries: 104560 (16.36 [sec])
# 20221009 | # of related queries: 98889 (16.11 [sec])
# 20221010 | # of related queries: 113926 (18.98 [sec])
# 20221011 | # of related queries: 132074 (21.21 [sec])
# 20221012 | # of related queries: 117769 (19.43 [sec])
# 20221013 | # of related queries: 113221 (18.48 [sec])
# 20221014 | # of related queries: 109993 (17.49 [sec])
# 20221015 | # of related queries: 106059 (17.04 [sec])
# 20221016 | # of related queries: 101720 (16.56 [sec])
# 20221017 | # of related queries: 114909 (19.07 [sec])
# 20221018 | # of related queries: 110601 (17.52 [sec])
# 20221019 | # of related queries: 107506 (17.52 [sec])
# 20221020 | # of related queries: 107637 (17.47 [sec])
# 20221021 | # of related queries: 111480 (17.82 [sec])
# 20221022 | # of related queries: 101213 (15.70 [sec])
# 20221023 | # of related queries: 97522 (15.73 [sec])
# 20221024 | # of related queries: 117006 (19.45 [sec])
# 20221025 | # of related queries: 111386 (20.92 [sec])
# 20221026 | # of related queries: 127919 (28.96 [sec])
# 20221027 | # of related queries: 134514 (32.94 [sec])
# 20221028 | # of related queries: 146673 (36.05 [sec])
# 20221029 | # of related queries: 145105 (38.22 [sec])
# 20221030 | # of related queries: 129372 (33.92 [sec])
# 20221031 | # of related queries: 127369 (29.90 [sec])
# 20221101 | # of related queries: 117732 (25.44 [sec])
# 20221102 | # of related queries: 141347 (28.25 [sec])
# 20221103 | # of related queries: 119339 (24.24 [sec])
# 20221104 | # of related queries: 129124 (25.42 [sec])
# 20221105 | # of related queries: 114551 (25.63 [sec])
# 20221106 | # of related queries: 104894 (24.32 [sec])
# 20221107 | # of related queries: 115580 (25.19 [sec])
# 20221108 | # of related queries: 109824 (23.65 [sec])
# 20221109 | # of related queries: 107265 (24.99 [sec])
# 20221110 | # of related queries: 111933 (24.00 [sec])
# 20221111 | # of related queries: 109053 (22.74 [sec])
# 20221112 | # of related queries: 97065 (21.01 [sec])
# 20221113 | # of related queries: 103757 (27.01 [sec])
# 20221114 | # of related queries: 109922 (27.32 [sec])
# 20221115 | # of related queries: 104298 (25.89 [sec])
# 20221116 | # of related queries: 100269 (25.09 [sec])
# 20221117 | # of related queries: 104840 (26.05 [sec])
# 20221118 | # of related queries: 100541 (22.42 [sec])
# 20221119 | # of related queries: 87312 (20.56 [sec])
# 20221120 | # of related queries: 87515 (22.19 [sec])
# 20221121 | # of related queries: 101641 (23.21 [sec])
# 20221122 | # of related queries: 98867 (23.34 [sec])
# 20221123 | # of related queries: 91752 (22.75 [sec])
# 20221124 | # of related queries: 94436 (22.32 [sec])
# 20221125 | # of related queries: 101031 (22.25 [sec])
# 20221126 | # of related queries: 85257 (20.34 [sec])
# 20221127 | # of related queries: 77052 (19.10 [sec])
# 20221128 | # of related queries: 92022 (21.98 [sec])
# 20221129 | # of related queries: 87621 (21.29 [sec])
# 20221130 | # of related queries: 77478 (18.32 [sec])
# 20221201 | # of related queries: 76769 (16.34 [sec])
# 20221202 | # of related queries: 78640 (16.54 [sec])
# 20221203 | # of related queries: 71121 (15.50 [sec])
# 20221204 | # of related queries: 66092 (15.00 [sec])
# 20221205 | # of related queries: 82223 (17.74 [sec])
# 20221206 | # of related queries: 74551 (15.61 [sec])
# 20221207 | # of related queries: 74391 (14.44 [sec])
# 20221208 | # of related queries: 76464 (13.93 [sec])
# 20221209 | # of related queries: 77608 (15.53 [sec])
# 20221210 | # of related queries: 66842 (14.11 [sec])
# 20221211 | # of related queries: 63743 (13.20 [sec])
# 20221212 | # of related queries: 77767 (14.92 [sec])
# 20221213 | # of related queries: 69296 (13.23 [sec])
# 20221214 | # of related queries: 71393 (13.31 [sec])
# 20221215 | # of related queries: 78208 (14.44 [sec])
# 20221216 | # of related queries: 76676 (14.01 [sec])
# 20221217 | # of related queries: 65337 (12.68 [sec])
# 20221218 | # of related queries: 68453 (13.06 [sec])
# 20221219 | # of related queries: 80497 (14.33 [sec])
# 20221220 | # of related queries: 80320 (14.25 [sec])
# 20221221 | # of related queries: 76643 (14.03 [sec])
# 20221222 | # of related queries: 78603 (14.17 [sec])
# 20221223 | # of related queries: 83484 (15.37 [sec])
# 20221224 | # of related queries: 73122 (13.89 [sec])
# 20221225 | # of related queries: 70535 (14.15 [sec])
# 20221226 | # of related queries: 90989 (17.20 [sec])
# 20221227 | # of related queries: 89140 (19.12 [sec])
# 20221228 | # of related queries: 94327 (19.47 [sec])
# 20221229 | # of related queries: 89621 (18.02 [sec])
# 20221230 | # of related queries: 79604 (16.12 [sec])
# 20221231 | # of related queries: 65445 (13.68 [sec])
# ======================================== 20230101 -> 20230331 ========================================
# 20230101 | # of related queries: 65874 (13.65 [sec])
# 20230102 | # of related queries: 84993 (16.91 [sec])
# 20230103 | # of related queries: 83226 (16.54 [sec])
# 20230104 | # of related queries: 82488 (15.61 [sec])
# 20230105 | # of related queries: 89491 (16.89 [sec])
# 20230106 | # of related queries: 94954 (16.49 [sec])
# 20230107 | # of related queries: 83597 (14.63 [sec])
# 20230108 | # of related queries: 75334 (13.75 [sec])
# 20230109 | # of related queries: 77266 (13.85 [sec])
# 20230110 | # of related queries: 87696 (15.98 [sec])
# 20230111 | # of related queries: 79942 (15.03 [sec])
# 20230112 | # of related queries: 85741 (16.44 [sec])
# 20230113 | # of related queries: 87012 (16.08 [sec])
# 20230114 | # of related queries: 70081 (12.89 [sec])
# 20230115 | # of related queries: 69439 (12.82 [sec])
# 20230116 | # of related queries: 84494 (15.53 [sec])
# 20230117 | # of related queries: 80882 (14.78 [sec])
# 20230118 | # of related queries: 78307 (14.27 [sec])
# 20230119 | # of related queries: 88270 (16.73 [sec])
# 20230120 | # of related queries: 89046 (16.21 [sec])
# 20230121 | # of related queries: 76271 (12.69 [sec])
# 20230122 | # of related queries: 70203 (12.32 [sec])
# 20230123 | # of related queries: 87508 (15.46 [sec])
# 20230124 | # of related queries: 79353 (14.10 [sec])
# 20230125 | # of related queries: 85171 (14.35 [sec])
# 20230126 | # of related queries: 86541 (14.27 [sec])
# 20230127 | # of related queries: 86604 (14.46 [sec])
# 20230128 | # of related queries: 78077 (13.06 [sec])
# 20230129 | # of related queries: 77634 (13.39 [sec])
# 20230130 | # of related queries: 86754 (15.09 [sec])
# 20230131 | # of related queries: 81370 (14.37 [sec])
# 20230201 | # of related queries: 82686 (14.42 [sec])
# 20230202 | # of related queries: 87549 (15.59 [sec])
# 20230203 | # of related queries: 93385 (16.16 [sec])
# 20230204 | # of related queries: 87163 (14.73 [sec])
# 20230205 | # of related queries: 84035 (14.89 [sec])
# 20230206 | # of related queries: 95903 (17.21 [sec])
# 20230207 | # of related queries: 91506 (16.78 [sec])
# 20230208 | # of related queries: 90398 (16.74 [sec])
# 20230209 | # of related queries: 87462 (15.33 [sec])
# 20230210 | # of related queries: 111194 (17.83 [sec])
# 20230211 | # of related queries: 93978 (15.97 [sec])
# 20230212 | # of related queries: 87269 (16.05 [sec])
# 20230213 | # of related queries: 103877 (19.40 [sec])
# 20230214 | # of related queries: 92833 (18.01 [sec])
# 20230215 | # of related queries: 98156 (19.27 [sec])
# 20230216 | # of related queries: 102500 (19.95 [sec])
# 20230217 | # of related queries: 109425 (19.54 [sec])
# 20230218 | # of related queries: 98583 (17.88 [sec])
# 20230219 | # of related queries: 107657 (19.89 [sec])
# 20230220 | # of related queries: 114853 (21.01 [sec])
# 20230221 | # of related queries: 108691 (20.23 [sec])
# 20230222 | # of related queries: 109525 (19.06 [sec])
# 20230223 | # of related queries: 108655 (19.19 [sec])
# 20230224 | # of related queries: 120978 (21.14 [sec])
# 20230225 | # of related queries: 109595 (19.37 [sec])
# 20230226 | # of related queries: 108020 (20.52 [sec])
# 20230227 | # of related queries: 117053 (23.10 [sec])
# 20230228 | # of related queries: 107362 (22.10 [sec])
# 20230301 | # of related queries: 109473 (22.09 [sec])
# 20230302 | # of related queries: 109133 (21.90 [sec])
# 20230303 | # of related queries: 117987 (21.51 [sec])
# 20230304 | # of related queries: 112419 (19.88 [sec])
# 20230305 | # of related queries: 111745 (19.85 [sec])
# 20230306 | # of related queries: 119727 (22.45 [sec])
# 20230307 | # of related queries: 110678 (20.66 [sec])
# 20230308 | # of related queries: 107806 (20.46 [sec])
# 20230309 | # of related queries: 107547 (20.25 [sec])
# 20230310 | # of related queries: 109628 (19.97 [sec])
# 20230311 | # of related queries: 99845 (18.43 [sec])
# 20230312 | # of related queries: 102574 (19.14 [sec])
# 20230313 | # of related queries: 116960 (22.54 [sec])
# 20230314 | # of related queries: 109057 (22.16 [sec])
# 20230315 | # of related queries: 107015 (20.96 [sec])
# 20230316 | # of related queries: 108710 (20.71 [sec])
# 20230317 | # of related queries: 117408 (21.56 [sec])
# 20230318 | # of related queries: 120874 (21.23 [sec])
# 20230319 | # of related queries: 112921 (20.70 [sec])
# 20230320 | # of related queries: 125578 (22.89 [sec])
# 20230321 | # of related queries: 101708 (19.19 [sec])
# 20230322 | # of related queries: 104577 (19.80 [sec])
# 20230323 | # of related queries: 113200 (21.43 [sec])
# 20230324 | # of related queries: 125803 (23.49 [sec])
# 20230325 | # of related queries: 121175 (22.08 [sec])
# 20230326 | # of related queries: 129010 (23.68 [sec])
# 20230327 | # of related queries: 125442 (23.72 [sec])
# 20230328 | # of related queries: 120681 (22.82 [sec])
# 20230329 | # of related queries: 116143 (22.17 [sec])
# 20230330 | # of related queries: 118485 (22.52 [sec])
# 20230331 | # of related queries: 126822 (23.55 [sec])
# ======================================== 20230401 -> 20230630 ========================================
# 20230401 | # of related queries: 119266 (22.06 [sec])
# 20230402 | # of related queries: 122153 (22.15 [sec])
# 20230403 | # of related queries: 127261 (23.94 [sec])
# 20230404 | # of related queries: 118616 (22.55 [sec])
# 20230405 | # of related queries: 116028 (22.63 [sec])
# 20230406 | # of related queries: 119094 (22.73 [sec])
# 20230407 | # of related queries: 117959 (21.10 [sec])
# 20230408 | # of related queries: 114330 (21.47 [sec])
# 20230409 | # of related queries: 116335 (22.78 [sec])
# 20230410 | # of related queries: 123205 (24.87 [sec])
# 20230411 | # of related queries: 121786 (24.15 [sec])
# 20230412 | # of related queries: 116289 (23.17 [sec])
# 20230413 | # of related queries: 119555 (23.86 [sec])
# 20230414 | # of related queries: 120730 (23.62 [sec])
# 20230415 | # of related queries: 121083 (23.60 [sec])
# 20230416 | # of related queries: 118865 (23.40 [sec])
# 20230417 | # of related queries: 127114 (24.02 [sec])
# 20230418 | # of related queries: 120636 (22.73 [sec])
# 20230419 | # of related queries: 124807 (23.53 [sec])
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# /tmp/ipykernel_43944/675360252.py in <module>
#       6         s = time.time()
#       7
# ----> 8         df_simple = simplify_search_log(get_log(target_date))
#       9         df_related_log = extract_road_related_queries(df_simple, target_road_code_set)
#      10
#
# /tmp/ipykernel_43944/574972274.py in get_log(date)
#      12         return cudf.DataFrame()
#      13     df = pd.read_csv(SEARCH_LOG_CSV(date), dtype=type_map)
# ---> 14     return cudf.from_pandas(df)
#
# /opt/conda/envs/rapids/lib/python3.8/contextlib.py in inner(*args, **kwds)
#      73         def inner(*args, **kwds):
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#      77
#
# /opt/conda/envs/rapids/lib/python3.8/site-packages/cudf/core/dataframe.py in from_pandas(obj, nan_as_null)
#    6319     """
#    6320     if isinstance(obj, pd.DataFrame):
# -> 6321         return DataFrame.from_pandas(obj, nan_as_null=nan_as_null)
#    6322     elif isinstance(obj, pd.Series):
#    6323         return Series.from_pandas(obj, nan_as_null=nan_as_null)
#
# /opt/conda/envs/rapids/lib/python3.8/contextlib.py in inner(*args, **kwds)
#      73         def inner(*args, **kwds):
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#      77
#
# /opt/conda/envs/rapids/lib/python3.8/site-packages/cudf/core/dataframe.py in from_pandas(cls, dataframe, nan_as_null)
#    4384             # columns for a single key
#    4385             if len(col_value.shape) == 1:
# -> 4386                 df[col_name] = column.as_column(
#    4387                     col_value.array, nan_as_null=nan_as_null
#    4388                 )
#
# /opt/conda/envs/rapids/lib/python3.8/site-packages/cudf/core/column/column.py in as_column(arbitrary, nan_as_null, dtype, length)
#    1979             )
#    1980         elif arb_dtype.kind in ("O", "U"):
# -> 1981             data = as_column(pa.Array.from_pandas(arbitrary), dtype=arb_dtype)
#    1982         else:
#    1983             data = as_column(
#
# /opt/conda/envs/rapids/lib/python3.8/site-packages/cudf/core/column/column.py in as_column(arbitrary, nan_as_null, dtype, length)
#    1774                 "https://issues.apache.org/jira/browse/ARROW-3802"
#    1775             )
# -> 1776         col = ColumnBase.from_arrow(arbitrary)
#    1777
#    1778         if isinstance(arbitrary, pa.NullArray):
#
# /opt/conda/envs/rapids/lib/python3.8/site-packages/cudf/core/column/column.py in from_arrow(cls, array)
#     300             return cudf.core.column.IntervalColumn.from_arrow(array)
#     301
# --> 302         result = libcudf.interop.from_arrow(data, data.column_names)[0]["None"]
#     303
#     304         return result._with_type_metadata(cudf_dtype_from_pa_type(array.type))
#
# cudf/_lib/interop.pyx in cudf._lib.interop.from_arrow()
#
# MemoryError: std::bad_alloc: out_of_memory: CUDA error at: /workspace/.conda-bld/work/include/rmm/mr/device/cuda_memory_resource.hpp:70: cudaErrorMemoryAllocation out of memory

# %%
df_simple = simplify_search_log(get_log('20230930'))
df_related_log = extract_road_related_queries(df_simple, target_road_code_set)

# %%
df_simple.shape, df_related_log.shape
# Out:
# ((656387, 6), (197082, 6))

# %%
df_simple.head()
# Out:
#     datetime start_code end_code       spec_datetime spec_type car_type
# 0 2023-09-30    6016006  1040121 2023-09-30 00:00:00         1        2
# 1 2023-09-30    212D006  5005021 2023-09-30 16:00:00         1        1
# 2 2023-09-30    1800111  1421003 2023-09-30 00:00:00         1        2
# 3 2023-09-30    8012001  1011031 2023-09-30 00:00:00         1        2
# 4 2023-09-30    5033006  9041130 2023-09-30 00:00:00         1        2

# %%
df_related_log.head()
# Out:
#              datetime start_code end_code       spec_datetime spec_type  \
# 0 2023-09-30 00:00:00    6016006  1040121 2023-09-30 00:00:00         1
# 1 2023-09-30 00:00:00    1800111  1421003 2023-09-30 00:00:00         1
# 2 2023-09-30 00:00:00    1201001  1800161 2023-09-30 00:00:00         1
# 3 2023-09-30 00:00:01    1040051  1400131 2023-09-29 01:00:00         1
# 4 2023-09-30 00:00:02    1410006  6016041 2023-09-30 00:00:00         1
#
#   car_type
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
