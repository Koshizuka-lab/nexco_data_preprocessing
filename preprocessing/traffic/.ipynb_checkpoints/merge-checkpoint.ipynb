# %% [markdown]
# # このファイルについて
# - about: トラカンデータと検索データのマージ
# - author: 松永
# - ref: ../cudf/1_1_traffic_merge_all.ipynb

# %%
import cudf
import cupy
import matplotlib.pyplot as plt
import missingno as msno
import numpy as np
import pandas as pd

# %%
cupy.cuda.Device(1).use()
# Out:
# <CUDA Device 1>

# %%
# TARGET_ROAD = 'kannetsu'
TARGET_ROAD = 'touhoku'

PERIOD = '20240507-20240831'

TRAFFIC_DIR = f'../../Input_processed_data/traffic'
TRAFFIC_CSV = f'{TRAFFIC_DIR}/{TARGET_ROAD}_{PERIOD}_2KP.csv'

SEARCH_COUNT_DIR = f'../../Input_processed_data/search_count'
SPECIFIED_SEARCH_COUNT_CSV = f'{SEARCH_COUNT_DIR}/search-count_specified_{PERIOD}.csv'
UNSPECIFIED_SEARCH_COUNT_CSV = f'{SEARCH_COUNT_DIR}/search-count_unspecified_{PERIOD}.csv'

# %%
df_traffic = cudf.from_pandas(
    pd.read_csv(
        TRAFFIC_CSV, parse_dates=True, index_col='datetime', 
        dtype={'start_code': str, 'end_code': str,}
    )
).reset_index()

print(df_traffic.shape)
df_traffic.head(3)
# Out:
# (4987008, 29)
#     datetime start_name end_name start_code end_code  start_pref_code  \
# 0 2024-05-07       浦和本線       岩槻    1040013  1040016               11
# 1 2024-05-07         岩槻     浦和本線    1040016  1040013               11
# 2 2024-05-07       浦和本線       岩槻    1040013  1040016               11
#
#    end_pref_code  start_lat   end_lat   start_lng  ...  lane_count  \
# 0             11   35.89012  35.93470  139.723697  ...           3
# 1             11   35.93470  35.89012  139.690750  ...           3
# 2             11   35.89012  35.93470  139.723697  ...           1
#
#    KP_distance    KP  start_KP  end_KP  direction limit_speed  OCC  allCars  \
# 0          5.7  5.47       4.8    10.5         下り       100.0  2.0     64.0
# 1          5.7  5.60      10.5     4.8         上り       100.0  6.0    141.0
# 2          5.7  7.30       4.8    10.5         下り       100.0  2.0     17.0
#
#    speed
# 0   94.0
# 1   80.0
# 2   85.0
#
# [3 rows x 29 columns]

# %% [markdown]
# # 検索データをマージ

# %% [markdown]
# ## 時間指定あり

# %%
df_specified = cudf.from_pandas(
    pd.read_csv(SPECIFIED_SEARCH_COUNT_CSV, parse_dates=True, index_col='passing_time', 
                dtype={'start_code': str, 'end_code': str})
).reset_index()

print(df_specified.shape)
df_specified.head(3)
# Out:
# (2693671, 4)
#          passing_time start_code end_code  search
# 0 2024-05-07 00:00:00    1040013  1040016       6
# 1 2024-05-07 00:05:00    1040013  1040016       5
# 2 2024-05-07 00:10:00    1040013  1040016       5

# %%
df_specified.tail(3)
# Out:
#                passing_time start_code end_code  search
# 2693668 2024-08-31 23:45:00    1800106  1800111       6
# 2693669 2024-08-31 23:50:00    1800106  1800111       0
# 2693670 2024-08-31 23:55:00    1800106  1800111       0

# %%
df_traffic = df_traffic.merge(
    df_specified, how='left', 
    left_on=['datetime', 'start_code', 'end_code'], right_on=['passing_time', 'start_code', 'end_code']
)
df_traffic.drop('passing_time', axis=1, inplace=True)
df_traffic.shape
# Out:
# (4987008, 30)

# %%
# 2021/4/2以降で欠損埋め
cond = (df_traffic.datetime >= pd.Timestamp('2021/4/2')) & df_traffic.search.isna()

df_traffic.loc[cond, 'search'] = 0

# %%
# %time msno.matrix(df_traffic.to_pandas(), labels=True)
# plt.show()

# %% [markdown]
# ## 時間指定なし

# %%
df_unspecified = cudf.from_pandas(
    pd.read_csv(UNSPECIFIED_SEARCH_COUNT_CSV, dtype={'start_code': str, 'end_code': str})
)

print(df_unspecified.shape)
df_unspecified.head(3)
# Out:
# (9360, 4)
#   search_date start_code end_code  search
# 0  2024-05-07    1040013  1040016  8263.0
# 1  2024-05-07    1040016  1040013  7474.0
# 2  2024-05-07    1040016  1040020  9478.0

# %%
df_unspecified.tail(3)
# Out:
#      search_date start_code end_code  search
# 9357  2024-08-31    1800096  1800106  2893.0
# 9358  2024-08-31    1800106  1800096  1879.0
# 9359  2024-08-31    1800106  1800111  2834.0

# %%
# 日付を表すカラムを追加
df_traffic['date'] = df_traffic.datetime.to_pandas().map(lambda dt: dt.date())

# 日付でマージ
df_traffic = df_traffic.merge(
    df_unspecified, how='left', 
    left_on=['date', 'start_code', 'end_code'], right_on=['search_date', 'start_code', 'end_code'],
    suffixes=('_specified', '_unspecified')
).drop(['date', 'search_date'], axis=1)

# %%
# 2021/4/2以降で欠損埋め
cond = (
    (df_traffic.datetime >= pd.Timestamp('2021/4/2'))
    & df_traffic.search_unspecified.isna()
)
df_traffic.loc[cond, 'search_unspecified'] = 0

# %%
# %time msno.matrix(df_traffic.to_pandas(), labels=True)
# plt.show()

# %% [markdown]
# # ~欠損値を確認~

# %% [markdown]
# ### 長期間にわたって線形補間できない欠損が存在することを確認

# %%
ROADS = [
    'kannetsu',
    'touhoku'
]
PERIODS = [
    # '20210401-20220331',
    # '20220401-20230331',
    # '20230401-20230930',
    '20231001-20240131'
]

# %%
def col_interpolate(df: cudf.DataFrame, cols: list, method='linear'):
    """
    dfのcol列内の欠損を区間ごとに線形補間する
    """
    grouped_intp = lambda g: g.reset_index(drop=True).loc[:, cols].interpolate(method=method, axis=0)
    
    df = df.sort_values(['start_code', 'end_code', 'KP', 'datetime']).reset_index(drop=True)
    interpolated = (df.to_pandas()
                    .groupby(['start_code', 'end_code', 'KP'])
                    .apply(grouped_intp)
                    .sort_index()
                    .reset_index())
    
    df_res = df.assign(**{col: interpolated[col] for col in cols})
    return df_res

# %%
for road in ROADS:
    for period in PERIODS:
        print('='*30, road, period, '='*30)

        df_traffic = cudf.from_pandas(
            pd.read_csv(
                f'{TRAFFIC_DIR}/{road}_{period}_2KP.csv', parse_dates=True, index_col='datetime', 
                dtype={'start_code': str, 'end_code': str,}
            )
        ).reset_index()

        df_traffic2 = col_interpolate(df_traffic, cols=['speed', 'OCC', 'allCars'], method='linear')

        # 線形補間ができなかった箇所を列挙
        for g_name, df_g in df_traffic2.loc[df_traffic2.speed.isna()].to_pandas().groupby(['start_name', 'end_name', 'KP']):
            print('-'*20, g_name, '-'*20)
            print('# of null:', df_g.shape[0])
            print('Period:', f'{df_g.datetime.iloc[0]} --> {df_g.datetime.iloc[-1]}')
            print()

        del df_traffic, df_traffic2
# Out:
# ============================== kannetsu 20231001-20240131 ==============================
# -------------------- ('坂戸西スマート', '東松山', 34.97) --------------------
# # of null: 35424
# Period: 2023-10-01 00:00:00 --> 2024-01-31 23:55:00
#
# -------------------- ('寄居ＰＡ', '本庄児玉', 64.91) --------------------
# # of null: 23520
# Period: 2023-10-01 00:00:00 --> 2023-12-21 15:55:00
#
# -------------------- ('東松山', '坂戸西スマート', 35.68) --------------------
# # of null: 35424
# Period: 2023-10-01 00:00:00 --> 2024-01-31 23:55:00
#
# -------------------- ('渋川伊香保', '駒寄ＰＡ', 102.53) --------------------
# # of null: 35424
# Period: 2023-10-01 00:00:00 --> 2024-01-31 23:55:00
#
# ============================== touhoku 20231001-20240131 ==============================
# -------------------- ('加須', '羽生', 34.256) --------------------
# # of null: 34692
# Period: 2023-10-01 00:00:00 --> 2024-01-29 10:55:00
#
# -------------------- ('宇都宮', '鹿沼', 100.261) --------------------
# # of null: 35424
# Period: 2023-10-01 00:00:00 --> 2024-01-31 23:55:00
#
# -------------------- ('岩槻', '蓮田スマート', 13.838) --------------------
# # of null: 35304
# Period: 2023-10-01 00:00:00 --> 2024-01-31 13:55:00
#
# -------------------- ('栃木', '岩舟ＪＣＴ', 69.404) --------------------
# # of null: 35424
# Period: 2023-10-01 00:00:00 --> 2024-01-31 23:55:00
#
# -------------------- ('白河', '那須高原ＳＡ', 168.082) --------------------
# # of null: 19704
# Period: 2023-10-01 00:00:00 --> 2023-12-08 09:55:00
#
# -------------------- ('羽生', '加須', 34.246) --------------------
# # of null: 34692
# Period: 2023-10-01 00:00:00 --> 2024-01-29 10:55:00
#
# -------------------- ('蓮田スマート', '岩槻', 13.8) --------------------
# # of null: 35268
# Period: 2023-10-01 00:00:00 --> 2024-01-31 10:55:00
#
# -------------------- ('鹿沼', '宇都宮', 100.261) --------------------
# # of null: 35424
# Period: 2023-10-01 00:00:00 --> 2024-01-31 23:55:00

# %% [markdown]
# ### 速度の欠損パターンを確認する

# %%
road = 'kannetsu'
# road = 'touhoku'

period = '20231001-20240131'

# %%
df_traffic = pd.read_csv(f'{TRAFFIC_DIR}/{road}_{period}_2KP.csv', dtype={'start_code': str, 'end_code': str,})
df_traffic.head(3)
# Out:
#               datetime start_name end_name start_code end_code  \
# 0  2023-10-01 00:00:00         所沢    大泉ＪＣＴ    1800006  1110210
# 1  2023-10-01 00:00:00      大泉ＪＣＴ       所沢    1110210  1800006
# 2  2023-10-01 00:00:00      大泉ＪＣＴ       所沢    1110210  1800006
#
#    start_pref_code  end_pref_code  start_lat   end_lat   start_lng  ...  \
# 0               11             13   35.80615  35.75582  139.535511  ...
# 1               13             11   35.75582  35.80615  139.601514  ...
# 2               13             11   35.75582  35.80615  139.601514  ...
#
#    lane_count  KP_distance    KP  start_KP  end_KP  direction  limit_speed  \
# 0           3          8.6  2.26       9.4     0.8         up        100.0
# 1           3          8.6  2.48       0.8     9.4       down        100.0
# 2           3          8.6  3.90       0.8     9.4       down        100.0
#
#    OCC  allCars  speed
# 0  2.0     54.0   82.0
# 1  2.0     71.0   97.0
# 2  2.0     64.0   86.0
#
# [3 rows x 29 columns]

# %%
def create_na_table(df: pd.DataFrame):
    na_table = df.isna().sum()
    na_percent_table = (df.isna().sum() / len(df_traffic)) * 100
    
    na_table = (pd.concat([na_table, na_percent_table], axis=1)
                .rename(columns={0: '# of null', 1: '% of null'})
                .pipe(lambda _df: _df.loc[_df['# of null'] > 0])
                .sort_values('% of null'))
    return na_table

# %%
create_na_table(df_traffic)
# Out:
#          # of null  % of null
# OCC         255048   5.217293
# allCars     255048   5.217293
# speed       260794   5.334834

# %%
cond1 = df_traffic.speed.isna() & df_traffic.OCC.isna()
cond2 = df_traffic.speed.isna() & df_traffic.OCC.notna()
cond3 = df_traffic.speed.isna() & df_traffic.allCars.notna()

df_tmp1 = df_traffic.loc[cond1]
print(len(df_tmp1))
df_tmp2 = df_traffic.loc[cond2]
print(len(df_tmp2))
df_tmp3 = df_traffic.loc[cond3]
print(len(df_tmp3))
# Out:
# 255048
# 5746
# 5746

# %%
df_tmp2.loc[:, ['OCC', 'allCars']].value_counts().reset_index().rename(columns={0: '# of null (speed)'})
# Out:
#      OCC  allCars  # of null (speed)
# 0    0.0      0.0               5658
# 1    0.0      1.0                  9
# 2    1.0     30.0                  6
# 3    1.0     20.0                  5
# 4    2.0     50.0                  5
# 5    2.0     45.0                  4
# 6    1.0     35.0                  4
# 7    2.0     40.0                  3
# 8    1.0     25.0                  3
# 9    1.0     27.0                  3
# 10   1.0     15.0                  2
# 11   1.0     40.0                  2
# 12   2.0     53.0                  2
# 13   2.0     46.0                  2
# 14   1.0     31.0                  2
# 15   1.0      2.0                  2
# 16   1.0      1.0                  2
# 17   2.0     44.0                  2
# 18   1.0     23.0                  2
# 19   1.0     28.0                  2
# 20   2.0     48.0                  1
# 21   2.0     47.0                  1
# 22   2.0     55.0                  1
# 23   2.0     51.0                  1
# 24   2.0     52.0                  1
# 25   2.0     42.0                  1
# 26   2.0     58.0                  1
# 27   3.0     57.0                  1
# 28   3.0     60.0                  1
# 29   2.0     43.0                  1
# 30   2.0      2.0                  1
# 31   2.0     41.0                  1
# 32   2.0     38.0                  1
# 33   2.0     37.0                  1
# 34   2.0     33.0                  1
# 35   2.0     28.0                  1
# 36   2.0      1.0                  1
# 37   1.0     43.0                  1
# 38   1.0     42.0                  1
# 39   1.0     39.0                  1
# 40   1.0     38.0                  1
# 41   1.0     34.0                  1
# 42   1.0     32.0                  1
# 43   1.0     24.0                  1
# 44   0.0     10.0                  1
# 45  20.0      1.0                  1

# %%
df_tmp3.loc[:, ['OCC', 'allCars']].value_counts().reset_index()
# Out:
#      OCC  allCars     0
# 0    0.0      0.0  5658
# 1    0.0      1.0     9
# 2    1.0     30.0     6
# 3    1.0     20.0     5
# 4    2.0     50.0     5
# 5    2.0     45.0     4
# 6    1.0     35.0     4
# 7    2.0     40.0     3
# 8    1.0     25.0     3
# 9    1.0     27.0     3
# 10   1.0     15.0     2
# 11   1.0     40.0     2
# 12   2.0     53.0     2
# 13   2.0     46.0     2
# 14   1.0     31.0     2
# 15   1.0      2.0     2
# 16   1.0      1.0     2
# 17   2.0     44.0     2
# 18   1.0     23.0     2
# 19   1.0     28.0     2
# 20   2.0     48.0     1
# 21   2.0     47.0     1
# 22   2.0     55.0     1
# 23   2.0     51.0     1
# 24   2.0     52.0     1
# 25   2.0     42.0     1
# 26   2.0     58.0     1
# 27   3.0     57.0     1
# 28   3.0     60.0     1
# 29   2.0     43.0     1
# 30   2.0      2.0     1
# 31   2.0     41.0     1
# 32   2.0     38.0     1
# 33   2.0     37.0     1
# 34   2.0     33.0     1
# 35   2.0     28.0     1
# 36   2.0      1.0     1
# 37   1.0     43.0     1
# 38   1.0     42.0     1
# 39   1.0     39.0     1
# 40   1.0     38.0     1
# 41   1.0     34.0     1
# 42   1.0     32.0     1
# 43   1.0     24.0     1
# 44   0.0     10.0     1
# 45  20.0      1.0     1

# %% [markdown]
# ### 道路別の欠損割合を確認

# %%
road = 'kannetsu'
# road = 'touhoku'

periods = [
    # '20210401-20220331',
    # '20220401-20230331',
    # '20230401-20230930',
    # '20231001-20240331',
    '20240401-20240506',
]

# %%
df_traffic = pd.DataFrame()

for period in periods:
    print(f'Loading {period}...')
    _df_traffic = pd.read_csv(f'{TRAFFIC_DIR}/{road}_{period}_2KP.csv', dtype={'start_code': str, 'end_code': str,})
    print(f'Finished.')
    df_traffic = pd.concat([df_traffic, _df_traffic])
# Out:
# Loading 20240401-20240506...
# Finished.

# %%
def create_na_table(df: pd.DataFrame):
    na_table = df.isna().sum()
    na_percent_table = (df.isna().sum() / len(df_traffic)) * 100
    
    na_table = (pd.concat([na_table, na_percent_table], axis=1)
                .rename(columns={0: '# of null', 1: '% of null'})
                .pipe(lambda _df: _df.loc[_df['# of null'] > 0])
                .sort_values('% of null'))
    return na_table

# %% [markdown]
# 5分間での欠損割合

# %%
df_traffic.shape
# Out:
# (1430784, 29)

# %%
create_na_table(df_traffic)
# Out:
#          # of null  % of null
# OCC         113940   7.963466
# allCars     113940   7.963466
# speed       115157   8.048524

# %% [markdown]
# 1時間での欠損割合

# %%
AGG_COLS = ['allCars', 'speed']
AGG_COLS_METHODS = {
    'allCars': 'sum', 
    'accum_speed': 'sum', 
}

# %%
sampling_rate = '1h'

# %%
# 1時間単位でそのままデータを取得すればいいカラム（静的カラム + 1日単位の時間指定なし検索数）
df_static = cudf.from_pandas(
    df_traffic
    .drop(AGG_COLS, axis=1)
    .assign(datetime=pd.to_datetime(df_traffic.datetime))
    .set_index('datetime')
    .groupby(['start_code', 'end_code', 'KP'])
    .apply(lambda g: g.asfreq(sampling_rate))
    .reset_index('datetime')
    .reset_index(drop=True)
)

df_static.head(3)
# Out:
#              datetime start_name end_name start_code end_code  \
# 0 2024-04-01 00:00:00      大泉ＪＣＴ       所沢    1110210  1800006
# 1 2024-04-01 01:00:00      大泉ＪＣＴ       所沢    1110210  1800006
# 2 2024-04-01 02:00:00      大泉ＪＣＴ       所沢    1110210  1800006
#
#    start_pref_code  end_pref_code  start_lat   end_lat   start_lng  ...  hour  \
# 0               13             11   35.75582  35.80615  139.601514  ...     0
# 1               13             11   35.75582  35.80615  139.601514  ...     1
# 2               13             11   35.75582  35.80615  139.601514  ...     2
#
#    minute  lane_count  KP_distance    KP  start_KP  end_KP  direction  \
# 0       0           3          8.6  2.48       0.8     9.4         下り
# 1       0           3          8.6  2.48       0.8     9.4         下り
# 2       0           3          8.6  2.48       0.8     9.4         下り
#
#   limit_speed  OCC
# 0       100.0  2.0
# 1       100.0  1.0
# 2       100.0  1.0
#
# [3 rows x 27 columns]

# %%
df_agg = cudf.from_pandas(
    df_traffic
    .assign(accum_speed=df_traffic['allCars'] * df_traffic['speed'])
    .assign(datetime=pd.to_datetime(df_traffic.datetime))
    .set_index('datetime')
    .groupby(['start_code', 'end_code', 'KP'])
    .apply(lambda g: g.resample(sampling_rate).agg(AGG_COLS_METHODS))
    .reset_index()
)

df_agg.head(3)
# Out:
#   start_code end_code    KP            datetime  allCars  accum_speed
# 0    1110210  1800006  2.48 2024-04-01 00:00:00    655.0      63481.0
# 1    1110210  1800006  2.48 2024-04-01 01:00:00    459.0      44792.0
# 2    1110210  1800006  2.48 2024-04-01 02:00:00    359.0      34110.0

# %%
df = df_static.merge(df_agg, on=['datetime', 'start_code', 'end_code', 'KP'])
df = df.assign(speed=df.accum_speed / (df.allCars + 1)).drop(['accum_speed'], axis=1)

# カラムの順番を揃える
df = df.loc[:, df_traffic.columns]
df.head()
# Out:
#              datetime start_name end_name start_code end_code  \
# 0 2024-04-18 08:00:00         川越   鶴ヶ島ＪＣＴ    1800016  1800021
# 1 2024-04-18 09:00:00         川越   鶴ヶ島ＪＣＴ    1800016  1800021
# 2 2024-04-18 10:00:00         川越   鶴ヶ島ＪＣＴ    1800016  1800021
# 3 2024-04-18 11:00:00         川越   鶴ヶ島ＪＣＴ    1800016  1800021
# 4 2024-04-18 12:00:00         川越   鶴ヶ島ＪＣＴ    1800016  1800021
#
#    start_pref_code  end_pref_code  start_lat   end_lat  start_lng  ...  \
# 0               11             11   35.89213  35.92886   139.4641  ...
# 1               11             11   35.89213  35.92886   139.4641  ...
# 2               11             11   35.89213  35.92886   139.4641  ...
# 3               11             11   35.89213  35.92886   139.4641  ...
# 4               11             11   35.89213  35.92886   139.4641  ...
#
#    lane_count  KP_distance     KP  start_KP  end_KP  direction limit_speed  \
# 0           3          6.8  26.82      21.2    28.0         下り       100.0
# 1           3          6.8  26.82      21.2    28.0         下り       100.0
# 2           3          6.8  26.82      21.2    28.0         下り       100.0
# 3           3          6.8  26.82      21.2    28.0         下り       100.0
# 4           3          6.8  26.82      21.2    28.0         下り       100.0
#
#     OCC  allCars      speed
# 0   9.0   3544.0  85.432440
# 1   9.0   3485.0  83.137407
# 2  10.0   3344.0  82.740807
# 3  10.0   3075.0  84.001625
# 4   7.0   2727.0  85.292889
#
# [5 rows x 29 columns]

# %%
# NaNはリサンプリングすると0になる
na_condition = df.speed == 0

# 制限速度で置換
# df.loc[na_condition, 'speed'] = df.loc[na_condition, 'limit_speed']

# %%
n_na = len(df.loc[na_condition])
percent_na = n_na / len(df) * 100

print(f'全体レコード数: {len(df)} | 欠損レコード数: {n_na} | 欠損レコード割合: {percent_na:.3f}[%]')
# Out:
# 全体レコード数: 119232 | 欠損レコード数: 9517 | 欠損レコード割合: 7.982[%]

# %%
na_table = df.isna().sum()
na_percent_table = (df.isna().sum() / len(df_traffic)) * 100
    
na_table = (pd.concat([na_table, na_percent_table], axis=1)
            .rename(columns={0: '# of null', 1: '% of null'})
            .pipe(lambda _df: _df.loc[_df['# of null'] > 0])
            .sort_values('% of null'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_24417/543058483.py in <module>
#       2 na_percent_table = (df.isna().sum() / len(df_traffic)) * 100
#       3
# ----> 4 na_table = (pd.concat([na_table, na_percent_table], axis=1)
#       5             .rename(columns={0: '# of null', 1: '% of null'})
#       6             .pipe(lambda _df: _df.loc[_df['# of null'] > 0])
#
# /opt/conda/envs/rapids/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/conda/envs/rapids/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
#     296         axis=axis,
#
# /opt/conda/envs/rapids/lib/python3.8/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     382                     "only Series and DataFrame objs are valid"
#     383                 )
# --> 384                 raise TypeError(msg)
#     385
#     386             ndims.add(obj.ndim)
#
# TypeError: cannot concatenate object of type '<class 'cudf.core.series.Series'>'; only Series and DataFrame objs are valid

# %% [markdown]
# ### 速度の欠損のみを制限速度で埋める
# → resampling後に行う

# %%
# def create_na_table(df: cudf.DataFrame):
#     na_table = df.isna().sum()
#     na_percent_table = (df.isna().sum() / len(df_traffic)) * 100
    
#     na_table = (cudf.concat([na_table, na_percent_table], axis=1)
#                 .rename(columns={0: '# of null', 1: '% of null'})
#                 .pipe(lambda _df: _df.loc[_df['# of null'] > 0])
#                 .sort_values('% of null'))
#     return na_table

# %%
# create_na_table(df_traffic)

# %%
# na_condition = df_traffic.speed.isna()

# # 制限速度で置換
# df_traffic.loc[na_condition, 'speed'] = df_traffic.loc[na_condition, 'limit_speed']

# %%
# create_na_table(df_traffic)

# %%
# %time msno.matrix(df_traffic.to_pandas(), labels=True)
# plt.show()

# %% [markdown]
# # 1時間単位にリサンプリング
#
# **研究室内のリサンプリング方式**
# $$
# \bar v_{h,k} = \frac{\sum_{i=0}^H q_{i,k} v_{i,k}}{\sum_{i=0}^H q_{i,k}}
# $$
#
# $q_{i,k}$: i番目の時間スロット, k番目の区間の5分間交通量
#
# $v_i$: i番目の時間スロット, k番目の区間の5分間速度
#
# $\bar v_{h,k}$: h番目の時間スロット, k番目の区間の1時間平均速度
#
#
# **NEXCOのリサンプリング方式**
# $$
# v_i = \frac{\sum_{i=k}^l q_{a_i} }{\sum_{i=k}^l q_{a_i} / v_i}
# $$
#
# $q$: 交通量, $v$: 速度
#
# ```
# 5分間交通量の車線別速度を12個分（計１時間）使用して、車線別の時間平均速度を調和平均にて算出。←時間的平均
# 各車線の時間平均速度を使用して、全車線の時間平均速度を調和平均にて算出。←空間的平均
# ```

# %%
AGG_COLS = ['allCars', 'speed', 'OCC', 'search_specified']
AGG_COLS_METHODS = {
    'allCars': 'sum', 
    'accum_speed': 'sum', 
    'OCC': 'mean', 
    'search_specified': 'sum'
}

# %%
sampling_rate = '1h'

# %% [markdown]
# 10/2以降の日付が重複

# %%
# 1時間単位でそのままデータを取得すればいいカラム（静的カラム + 1日単位の時間指定なし検索数）
df_static = cudf.from_pandas(
    df_traffic
    .drop(AGG_COLS, axis=1)
    .set_index('datetime')
    .to_pandas()
    .groupby(['start_code', 'end_code', 'KP'])
    .apply(lambda g: g.asfreq(sampling_rate))
    .reset_index('datetime')
    .reset_index(drop=True)
)

df_static.head(3)
# Out:
#              datetime start_name end_name start_code end_code  \
# 0 2024-05-07 00:00:00      大泉ＪＣＴ       所沢    1110210  1800006
# 1 2024-05-07 01:00:00      大泉ＪＣＴ       所沢    1110210  1800006
# 2 2024-05-07 02:00:00      大泉ＪＣＴ       所沢    1110210  1800006
#
#    start_pref_code  end_pref_code  start_lat   end_lat   start_lng  ...  hour  \
# 0               13             11   35.75582  35.80615  139.601514  ...     0
# 1               13             11   35.75582  35.80615  139.601514  ...     1
# 2               13             11   35.75582  35.80615  139.601514  ...     2
#
#    minute  lane_count  KP_distance    KP  start_KP  end_KP  direction  \
# 0       0           3          8.6  2.48       0.8     9.4         下り
# 1       0           3          8.6  2.48       0.8     9.4         下り
# 2       0           3          8.6  2.48       0.8     9.4         下り
#
#   limit_speed  search_unspecified
# 0       100.0              6546.0
# 1       100.0              6546.0
# 2       100.0              6546.0
#
# [3 rows x 27 columns]

# %%
df_static.tail(3)
# Out:
#                   datetime start_name end_name start_code end_code  \
# 387501 2024-08-31 21:00:00         昭和  沼田(関越道)    1800106  1800111
# 387502 2024-08-31 22:00:00         昭和  沼田(関越道)    1800106  1800111
# 387503 2024-08-31 23:00:00         昭和  沼田(関越道)    1800106  1800111
#
#         start_pref_code  end_pref_code  start_lat  end_lat   start_lng  ...  \
# 387501               10             10   36.61077  36.6519  139.070694  ...
# 387502               10             10   36.61077  36.6519  139.070694  ...
# 387503               10             10   36.61077  36.6519  139.070694  ...
#
#         hour  minute  lane_count  KP_distance      KP  start_KP  end_KP  \
# 387501    21       0           0          5.2  125.37     120.7   125.9
# 387502    22       0           0          5.2  125.37     120.7   125.9
# 387503    23       0           0          5.2  125.37     120.7   125.9
#
#         direction limit_speed  search_unspecified
# 387501         下り        80.0              2834.0
# 387502         下り        80.0              2834.0
# 387503         下り        80.0              2834.0
#
# [3 rows x 27 columns]

# %%
df_agg = cudf.from_pandas(
    df_traffic
    .assign(accum_speed=df_traffic['allCars'] * df_traffic['speed'])
    .set_index('datetime')
    .to_pandas()
    .groupby(['start_code', 'end_code', 'KP'])
    .apply(lambda g: g.resample(sampling_rate).agg(AGG_COLS_METHODS))
    .reset_index()
)

df_agg.head(3)
# Out:
#   start_code end_code    KP            datetime  allCars  accum_speed  \
# 0    1110210  1800006  2.48 2024-05-07 00:00:00    526.0      51714.0
# 1    1110210  1800006  2.48 2024-05-07 01:00:00    417.0      40475.0
# 2    1110210  1800006  2.48 2024-05-07 02:00:00    340.0      32688.0
#
#         OCC  search_specified
# 0  1.666667                51
# 1  1.333333                37
# 2  1.083333                 9

# %%
df = df_static.merge(df_agg, on=['datetime', 'start_code', 'end_code', 'KP'])
df['speed'] = df.accum_speed / (df.allCars + 1)
df = df.drop(['accum_speed'], axis=1)

# カラムの順番を揃える
df = df.loc[:, df_traffic.columns]
df.head()
# Out:
#              datetime start_name end_name start_code end_code  \
# 0 2024-07-31 16:00:00      大泉ＪＣＴ       所沢    1110210  1800006
# 1 2024-07-31 17:00:00      大泉ＪＣＴ       所沢    1110210  1800006
# 2 2024-07-31 18:00:00      大泉ＪＣＴ       所沢    1110210  1800006
# 3 2024-07-31 19:00:00      大泉ＪＣＴ       所沢    1110210  1800006
# 4 2024-07-31 20:00:00      大泉ＪＣＴ       所沢    1110210  1800006
#
#    start_pref_code  end_pref_code  start_lat   end_lat   start_lng  ...   KP  \
# 0               13             11   35.75582  35.80615  139.601514  ...  8.1
# 1               13             11   35.75582  35.80615  139.601514  ...  8.1
# 2               13             11   35.75582  35.80615  139.601514  ...  8.1
# 3               13             11   35.75582  35.80615  139.601514  ...  8.1
# 4               13             11   35.75582  35.80615  139.601514  ...  8.1
#
#    start_KP  end_KP  direction limit_speed       OCC  allCars      speed  \
# 0       0.8     9.4         下り       100.0  4.916667   2628.0  87.863066
# 1       0.8     9.4         下り       100.0  5.083333   2337.0  70.653550
# 2       0.8     9.4         下り       100.0  6.833333   1883.0  45.364650
# 3       0.8     9.4         下り       100.0  5.416667   1162.0  44.263113
# 4       0.8     9.4         下り       100.0  4.583333   1093.0  61.073126
#
#    search_specified  search_unspecified
# 0                19              5184.0
# 1                45              5184.0
# 2                31              5184.0
# 3                43              5184.0
# 4                29              5184.0
#
# [5 rows x 31 columns]

# %%
assert df.shape == (len(df_traffic) / 12, df_traffic.shape[-1])

# %% [markdown]
# ### 速度の欠損のみを制限速度で埋める

# %%
# NaNはリサンプリングすると0になる
na_condition = df.speed == 0

# 制限速度で置換
df.loc[na_condition, 'speed'] = df.loc[na_condition, 'limit_speed']

# %%
# %time msno.matrix(df.to_pandas(), labels=True)
plt.show()
# Out:
# CPU times: user 2.87 s, sys: 7.06 s, total: 9.92 s
# Wall time: 1.46 s

# %% [markdown]
# # 最終確認・保存

# %%
df = df.sort_values(['start_code', 'end_code', 'KP', 'datetime']).reset_index(drop=True)
df.head(3)
# Out:
#              datetime start_name end_name start_code end_code  \
# 0 2024-05-07 00:00:00      大泉ＪＣＴ       所沢    1110210  1800006
# 1 2024-05-07 01:00:00      大泉ＪＣＴ       所沢    1110210  1800006
# 2 2024-05-07 02:00:00      大泉ＪＣＴ       所沢    1110210  1800006
#
#    start_pref_code  end_pref_code  start_lat   end_lat   start_lng  ...    KP  \
# 0               13             11   35.75582  35.80615  139.601514  ...  2.48
# 1               13             11   35.75582  35.80615  139.601514  ...  2.48
# 2               13             11   35.75582  35.80615  139.601514  ...  2.48
#
#    start_KP  end_KP  direction limit_speed       OCC  allCars      speed  \
# 0       0.8     9.4         下り       100.0  1.666667    526.0  98.129032
# 1       0.8     9.4         下り       100.0  1.333333    417.0  96.830144
# 2       0.8     9.4         下り       100.0  1.083333    340.0  95.859238
#
#    search_specified  search_unspecified
# 0                51              6546.0
# 1                37              6546.0
# 2                 9              6546.0
#
# [3 rows x 31 columns]

# %%
df.tail(3)
# Out:
#                   datetime start_name end_name start_code end_code  \
# 387501 2024-08-31 21:00:00         昭和  沼田(関越道)    1800106  1800111
# 387502 2024-08-31 22:00:00         昭和  沼田(関越道)    1800106  1800111
# 387503 2024-08-31 23:00:00         昭和  沼田(関越道)    1800106  1800111
#
#         start_pref_code  end_pref_code  start_lat  end_lat   start_lng  ...  \
# 387501               10             10   36.61077  36.6519  139.070694  ...
# 387502               10             10   36.61077  36.6519  139.070694  ...
# 387503               10             10   36.61077  36.6519  139.070694  ...
#
#             KP  start_KP  end_KP  direction limit_speed   OCC allCars  speed  \
# 387501  125.37     120.7   125.9         下り        80.0  <NA>     0.0   80.0
# 387502  125.37     120.7   125.9         下り        80.0  <NA>     0.0   80.0
# 387503  125.37     120.7   125.9         下り        80.0  <NA>     0.0   80.0
#
#         search_specified  search_unspecified
# 387501                26              2834.0
# 387502                29              2834.0
# 387503                21              2834.0
#
# [3 rows x 31 columns]

# %%
# %time msno.matrix(df.to_pandas(), labels=True)
plt.show()
# Out:
# CPU times: user 1.38 s, sys: 304 ms, total: 1.68 s
# Wall time: 1.41 s

# %%
OUTPUT_FILE = f'{TRAFFIC_DIR}/merged_1h_{TARGET_ROAD}_{PERIOD}_2KP.csv'
OUTPUT_FILE
# Out:
# '../../Input_processed_data/traffic/merged_1h_kannetsu_20240507-20240831_2KP.csv'

# %%
# %time df.to_pandas().to_csv(OUTPUT_FILE, index=False)
# Out:
# CPU times: user 8.7 s, sys: 10.8 ms, total: 8.71 s
# Wall time: 8.71 s

# %%
# !head -n5 "$OUTPUT_FILE"
# Out:
# datetime,start_name,end_name,start_code,end_code,start_pref_code,end_pref_code,start_lat,end_lat,start_lng,end_lng,start_degree,end_degree,month,day,dayofweek,is_holiday,hour,minute,lane_count,KP_distance,KP,start_KP,end_KP,direction,limit_speed,OCC,allCars,speed,search_specified,search_unspecified
# 2024-05-07 00:00:00,大泉ＪＣＴ,所沢,1110210,1800006,13,11,35.75582,35.80615,139.6015138888889,139.5355111111111,8.0,4.0,5,7,2,0,0,0,3,8.6,2.48,0.8,9.4,下り,100.0,1.6666666666666667,526.0,98.12903225806451,51,6546.0
# 2024-05-07 01:00:00,大泉ＪＣＴ,所沢,1110210,1800006,13,11,35.75582,35.80615,139.6015138888889,139.5355111111111,8.0,4.0,5,7,2,0,1,0,3,8.6,2.48,0.8,9.4,下り,100.0,1.3333333333333333,417.0,96.83014354066985,37,6546.0
# 2024-05-07 02:00:00,大泉ＪＣＴ,所沢,1110210,1800006,13,11,35.75582,35.80615,139.6015138888889,139.5355111111111,8.0,4.0,5,7,2,0,2,0,3,8.6,2.48,0.8,9.4,下り,100.0,1.0833333333333333,340.0,95.85923753665689,9,6546.0
# 2024-05-07 03:00:00,大泉ＪＣＴ,所沢,1110210,1800006,13,11,35.75582,35.80615,139.6015138888889,139.5355111111111,8.0,4.0,5,7,2,0,3,0,3,8.6,2.48,0.8,9.4,下り,100.0,1.4166666666666667,412.0,95.1138014527845,51,6546.0

# %%
# !tail -n5 "$OUTPUT_FILE"
# Out:
# 2024-08-31 19:00:00,昭和,沼田(関越道),1800106,1800111,10,10,36.61077,36.6519,139.07069444444443,139.07329444444443,4.0,4.0,8,31,6,1,19,0,0,5.200000000000003,125.37,120.7,125.9,下り,80.0,,0.0,80.0,70,2834.0
# 2024-08-31 20:00:00,昭和,沼田(関越道),1800106,1800111,10,10,36.61077,36.6519,139.07069444444443,139.07329444444443,4.0,4.0,8,31,6,1,20,0,0,5.200000000000003,125.37,120.7,125.9,下り,80.0,,0.0,80.0,51,2834.0
# 2024-08-31 21:00:00,昭和,沼田(関越道),1800106,1800111,10,10,36.61077,36.6519,139.07069444444443,139.07329444444443,4.0,4.0,8,31,6,1,21,0,0,5.200000000000003,125.37,120.7,125.9,下り,80.0,,0.0,80.0,26,2834.0
# 2024-08-31 22:00:00,昭和,沼田(関越道),1800106,1800111,10,10,36.61077,36.6519,139.07069444444443,139.07329444444443,4.0,4.0,8,31,6,1,22,0,0,5.200000000000003,125.37,120.7,125.9,下り,80.0,,0.0,80.0,29,2834.0
# 2024-08-31 23:00:00,昭和,沼田(関越道),1800106,1800111,10,10,36.61077,36.6519,139.07069444444443,139.07329444444443,4.0,4.0,8,31,6,1,23,0,0,5.200000000000003,125.37,120.7,125.9,下り,80.0,,0.0,80.0,21,2834.0

# %%
# !du -h "$TRAFFIC_DIR"/*
# Out:
# 40K	../../Input_processed_data/traffic/Untitled.ipynb
# 0	../../Input_processed_data/traffic/bak/.ipynb_checkpoints
# 26G	../../Input_processed_data/traffic/bak
# 2.7G	../../Input_processed_data/traffic/kannetsu_20210401-20220331_2KP.csv
# 6.7G	../../Input_processed_data/traffic/kannetsu_20210401-20230930_2KP.csv
# 7.6G	../../Input_processed_data/traffic/kannetsu_20210401-20240131_2KP.csv
# 2.7G	../../Input_processed_data/traffic/kannetsu_20220401-20230331_2KP.csv
# 1.4G	../../Input_processed_data/traffic/kannetsu_20230401-20230930_2KP.csv
# 915M	../../Input_processed_data/traffic/kannetsu_20231001-20240131_2KP.csv
# 1.4G	../../Input_processed_data/traffic/kannetsu_20231001-20240331_2KP.csv
# 722M	../../Input_processed_data/traffic/kannetsu_20240201-20240506_2KP.csv
# 271M	../../Input_processed_data/traffic/kannetsu_20240401-20240506_2KP.csv
# 880M	../../Input_processed_data/traffic/kannetsu_20240507-20240831_2KP.csv
# 265M	../../Input_processed_data/traffic/merged_1h_kannetsu_20210401-20220331_2KP.csv
# 659M	../../Input_processed_data/traffic/merged_1h_kannetsu_20210401-20230930_2KP.csv
# 752M	../../Input_processed_data/traffic/merged_1h_kannetsu_20210401-20240131_2KP.csv
# 263M	../../Input_processed_data/traffic/merged_1h_kannetsu_20220401-20230331_2KP.csv
# 132M	../../Input_processed_data/traffic/merged_1h_kannetsu_20230401-20230930_2KP.csv
# 89M	../../Input_processed_data/traffic/merged_1h_kannetsu_20231001-20240131_2KP.csv
# 133M	../../Input_processed_data/traffic/merged_1h_kannetsu_20231001-20240331_2KP.csv
# 27M	../../Input_processed_data/traffic/merged_1h_kannetsu_20240401-20240506_2KP.csv
# 85M	../../Input_processed_data/traffic/merged_1h_kannetsu_20240507-20240831_2KP.csv
# 286M	../../Input_processed_data/traffic/merged_1h_touhoku_20210401-20220331_2KP.csv
# 713M	../../Input_processed_data/traffic/merged_1h_touhoku_20210401-20230930_2KP.csv
# 813M	../../Input_processed_data/traffic/merged_1h_touhoku_20210401-20240131_2KP.csv
# 285M	../../Input_processed_data/traffic/merged_1h_touhoku_20220401-20230331_2KP.csv
# 143M	../../Input_processed_data/traffic/merged_1h_touhoku_20230401-20230930_2KP.csv
# 96M	../../Input_processed_data/traffic/merged_1h_touhoku_20231001-20240131_2KP.csv
# 144M	../../Input_processed_data/traffic/merged_1h_touhoku_20231001-20240331_2KP.csv
# 29M	../../Input_processed_data/traffic/merged_1h_touhoku_20240401-20240506_2KP.csv
# 3.5G	../../Input_processed_data/traffic/raw_kannetsu_20210401-20220331_2KP.csv
# 3.4G	../../Input_processed_data/traffic/raw_kannetsu_20220401-20230331_2KP.csv
# 1.6G	../../Input_processed_data/traffic/raw_kannetsu_20230401-20230930_2KP.csv
# 1.1G	../../Input_processed_data/traffic/raw_kannetsu_20231001-20240131_2KP.csv
# 816M	../../Input_processed_data/traffic/raw_kannetsu_20240201-20240506_2KP.csv
# 994M	../../Input_processed_data/traffic/raw_kannetsu_20240507-20240831_2KP.csv
# 4.4G	../../Input_processed_data/traffic/raw_touhoku_20210401-20220331_2KP.csv
# 3.5G	../../Input_processed_data/traffic/raw_touhoku_20220401-20230331_2KP.csv
# 1.7G	../../Input_processed_data/traffic/raw_touhoku_20230401-20230930_2KP.csv
# 1.1G	../../Input_processed_data/traffic/raw_touhoku_20231001-20240131_2KP.csv
# 884M	../../Input_processed_data/traffic/raw_touhoku_20240201-20240506_2KP.csv
# 1.1G	../../Input_processed_data/traffic/raw_touhoku_20240507-20240831_2KP.csv
# 2.9G	../../Input_processed_data/traffic/touhoku_20210401-20220331_2KP.csv
# 7.2G	../../Input_processed_data/traffic/touhoku_20210401-20230930_2KP.csv
# 8.2G	../../Input_processed_data/traffic/touhoku_20210401-20240131_2KP.csv
# 2.9G	../../Input_processed_data/traffic/touhoku_20220401-20230331_2KP.csv
# 1.5G	../../Input_processed_data/traffic/touhoku_20230401-20230930_2KP.csv
# 992M	../../Input_processed_data/traffic/touhoku_20231001-20240131_2KP.csv
# 1.5G	../../Input_processed_data/traffic/touhoku_20231001-20240331_2KP.csv
# 785M	../../Input_processed_data/traffic/touhoku_20240201-20240506_2KP.csv
# 295M	../../Input_processed_data/traffic/touhoku_20240401-20240506_2KP.csv
# 957M	../../Input_processed_data/traffic/touhoku_20240507-20240831_2KP.csv
